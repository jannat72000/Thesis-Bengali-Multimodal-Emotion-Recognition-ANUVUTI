# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
from IPython.display import Audio
import librosa
import librosa.display

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
data_dir = 'E:\\Capstone\\Dataset\\Noisy_Audio'

# %%
# Initialize empty lists for features and labels
features = []
labels = []
for folder in os.listdir(data_dir):
    folder_path = os.path.join(data_dir, folder)
    if os.path.isdir(folder_path):
        emotion_label = folder.split('_')[-1]  # Extract the emotion label from the folder name
        print(emotion_label)

        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if file_path.endswith('.wav'):
                # Load the audio file and extract features
                audio, sr = librosa.load(file_path, duration=3)  # Adjust the duration as needed
                mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40) #13
                mfcc_mean = np.mean(mfcc, axis=1)
                features.append(mfcc_mean)
                labels.append(emotion_label)
# Out:
# Angry
# Disgust
# Fear
# Happy
# Neutral
# Sad
# Surprise

# %%
features = np.array(features)
labels = np.array(labels)

# %%
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# %%
# Define the emotions and the number of samples to select from each emotion
emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad','Surprise']
num_samples_per_emotion = 2
# Initialize empty lists for storing the selected samples
selected_samples = []

# %%
# Iterate through the emotions and select samples
for emotion in emotions:
    emotion_dir = os.path.join(data_dir, f'{emotion}')
    audio_files = os.listdir(emotion_dir)
    selected_files = np.random.choice(audio_files, size=num_samples_per_emotion, replace=False)
    
    for file_name in selected_files:
        file_path = os.path.join(emotion_dir, file_name)
        audio, sr = librosa.load(file_path, duration=3)
        selected_samples.append((audio, sr, emotion))

# %%
for i in range(len(selected_samples)):
    print(selected_samples[i][-1])
# Out:
# Angry
# Angry
# Disgust
# Disgust
# Fear
# Fear
# Happy
# Happy
# Neutral
# Neutral
# Sad
# Sad
# Surprise
# Surprise

# %%
# Plot the selected samples
num_samples = len(selected_samples)
plt.figure(figsize=(8, 4 * num_samples))

for i, (audio, sr, emotion) in enumerate(selected_samples):
    plt.subplot(num_samples, 1, i + 1)
    plt.plot(audio)
    plt.title(f'Waveform - {emotion}')

plt.tight_layout()
plt.show()

# %%
# Calculate the spectrogram
spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr)

# Convert power spectrogram to dB scale
spectrogram_db = librosa.power_to_db(spectrogram, ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(10, 3))
librosa.display.specshow(spectrogram_db, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Surprise Spectrogram')
plt.tight_layout()
plt.show()
Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Apply audio transformations (e.g., noise addition, time stretching, pitch shifting)
augmented_features = []
augmented_labels = []

for feature, label in zip(features, labels):
    augmented_features.append(feature)
    augmented_labels.append(label)
    
    # Apply noise addition
    noise = np.random.randn(len(feature))
    augmented_features.append(feature + 0.005 * noise)  # Adjust the noise magnitude as needed
    augmented_labels.append(label)
    
    # Apply time stretching
    augmented_features.append(librosa.effects.time_stretch(feature, rate=1.2))  # Adjust the rate as needed
    augmented_labels.append(label)
    
    # Apply pitch shifting
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

print('Original samples:', len(features))
# Out:
# Original samples: 1032

# %%
# Define a list to store the preprocessed data
preprocessed_data = []
file_list = os.listdir(data_dir)
# Iterate over the files
for filename in file_list:
    file_path = os.path.join(data_dir, filename)
    
    # Skip non-audio files
    if not filename.endswith('.wav'):
        continue

    # Load the audio file and obtain the waveform and sample rate
    waveform, sr = librosa.load(file_path, sr=None, dtype=np.float32)

    # Resample the audio if needed
    if sr != 22050:
        waveform = librosa.resample(waveform, sr, 22050)
        sr = 22050

# %%
# Encode the emotion labels
label_mapping = {'Angry': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise' : 6}
encoded_labels = np.array([label_mapping[label] for label in labels])

# Convert the emotion labels to categorical format
num_classes = len(label_mapping)
y_categorical = to_categorical(encoded_labels, num_classes)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, y_categorical, test_size=0.2, random_state=42)

# Reshape the input features
X_train = X_train.reshape((*X_train.shape, 1))
X_test = X_test.reshape((*X_test.shape, 1))

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (825, 40, 1)
# y_train shape: (825, 7)
# X_test shape: (207, 40, 1)
# y_test shape: (207, 7)

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(40, 1, 1), padding='same'))
model.add(Dropout(0.1))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 40, 1, 64)         640
#
#  dropout_8 (Dropout)         (None, 40, 1, 64)         0
#
#  flatten_4 (Flatten)         (None, 2560)              0
#
#  dense_8 (Dense)             (None, 512)               1311232
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 1315463 (5.02 MB)
# Trainable params: 1315463 (5.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)

print("Test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 2s 22ms/step - loss: 5.8610 - accuracy: 0.2230 - val_loss: 1.8324 - val_accuracy: 0.3333
# Epoch 2/100
# 26/26 [==============================] - 0s 15ms/step - loss: 1.7700 - accuracy: 0.3794 - val_loss: 1.3801 - val_accuracy: 0.4928
# Epoch 3/100
# 26/26 [==============================] - 0s 16ms/step - loss: 1.4473 - accuracy: 0.4776 - val_loss: 1.2974 - val_accuracy: 0.4879
# Epoch 4/100
# 26/26 [==============================] - 0s 15ms/step - loss: 1.2883 - accuracy: 0.5200 - val_loss: 1.2780 - val_accuracy: 0.5411
# Epoch 5/100
# 26/26 [==============================] - 0s 15ms/step - loss: 1.1446 - accuracy: 0.5685 - val_loss: 1.1758 - val_accuracy: 0.5894
# Epoch 6/100
# 26/26 [==============================] - 0s 15ms/step - loss: 1.1122 - accuracy: 0.5733 - val_loss: 1.1773 - val_accuracy: 0.5797
# Epoch 7/100
# 26/26 [==============================] - 0s 18ms/step - loss: 1.0100 - accuracy: 0.6036 - val_loss: 1.0785 - val_accuracy: 0.6329
# Epoch 8/100
# 26/26 [==============================] - 1s 20ms/step - loss: 0.9124 - accuracy: 0.6594 - val_loss: 1.1492 - val_accuracy: 0.6039
# Epoch 9/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.8560 - accuracy: 0.6812 - val_loss: 1.0248 - val_accuracy: 0.5894
# Epoch 10/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.7373 - accuracy: 0.7345 - val_loss: 1.0573 - val_accuracy: 0.6232
# Epoch 11/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.6952 - accuracy: 0.7515 - val_loss: 0.9373 - val_accuracy: 0.6618
# Epoch 12/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.6443 - accuracy: 0.7624 - val_loss: 1.0319 - val_accuracy: 0.6667
# Epoch 13/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.5885 - accuracy: 0.7964 - val_loss: 1.0208 - val_accuracy: 0.6280
# Epoch 14/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.6197 - accuracy: 0.7721 - val_loss: 0.9857 - val_accuracy: 0.6232
# Epoch 15/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.5354 - accuracy: 0.8097 - val_loss: 0.9291 - val_accuracy: 0.6667
# Epoch 16/100
# 26/26 [==============================] - 1s 20ms/step - loss: 0.5060 - accuracy: 0.8218 - val_loss: 0.9089 - val_accuracy: 0.6763
# Epoch 17/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.4568 - accuracy: 0.8376 - val_loss: 0.9024 - val_accuracy: 0.6908
# Epoch 18/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.3725 - accuracy: 0.8715 - val_loss: 1.2969 - val_accuracy: 0.6329
# Epoch 19/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.3762 - accuracy: 0.8655 - val_loss: 0.8648 - val_accuracy: 0.7343
# Epoch 20/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.3256 - accuracy: 0.8945 - val_loss: 0.9487 - val_accuracy: 0.6860
# Epoch 21/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2730 - accuracy: 0.9176 - val_loss: 1.0780 - val_accuracy: 0.6329
# Epoch 22/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2829 - accuracy: 0.9079 - val_loss: 0.9866 - val_accuracy: 0.6860
# Epoch 23/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2230 - accuracy: 0.9442 - val_loss: 0.9736 - val_accuracy: 0.7295
# Epoch 24/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2105 - accuracy: 0.9358 - val_loss: 1.1026 - val_accuracy: 0.6473
# Epoch 25/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2074 - accuracy: 0.9297 - val_loss: 0.9402 - val_accuracy: 0.7150
# Epoch 26/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1868 - accuracy: 0.9406 - val_loss: 1.1083 - val_accuracy: 0.6957
# Epoch 27/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1465 - accuracy: 0.9624 - val_loss: 0.9574 - val_accuracy: 0.7633
# Epoch 28/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1446 - accuracy: 0.9527 - val_loss: 0.9759 - val_accuracy: 0.7246
# Epoch 29/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1334 - accuracy: 0.9564 - val_loss: 1.0449 - val_accuracy: 0.7440
# Epoch 30/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1114 - accuracy: 0.9770 - val_loss: 0.9859 - val_accuracy: 0.7488
# Epoch 31/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1031 - accuracy: 0.9758 - val_loss: 0.9941 - val_accuracy: 0.7488
# Epoch 32/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1261 - accuracy: 0.9612 - val_loss: 1.0163 - val_accuracy: 0.7440
# Epoch 33/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1118 - accuracy: 0.9697 - val_loss: 0.9535 - val_accuracy: 0.7874
# Epoch 34/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0730 - accuracy: 0.9867 - val_loss: 0.9763 - val_accuracy: 0.7681
# Epoch 35/100
# 26/26 [==============================] - 0s 19ms/step - loss: 0.0726 - accuracy: 0.9842 - val_loss: 0.9640 - val_accuracy: 0.7681
# Epoch 36/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0551 - accuracy: 0.9915 - val_loss: 0.9876 - val_accuracy: 0.7488
# Epoch 37/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0502 - accuracy: 0.9891 - val_loss: 0.9801 - val_accuracy: 0.7536
# Epoch 38/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0497 - accuracy: 0.9903 - val_loss: 1.1117 - val_accuracy: 0.7585
# Epoch 39/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0534 - accuracy: 0.9903 - val_loss: 0.9925 - val_accuracy: 0.7778
# Epoch 40/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0617 - accuracy: 0.9842 - val_loss: 1.0685 - val_accuracy: 0.7536
# Epoch 41/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0496 - accuracy: 0.9927 - val_loss: 1.1357 - val_accuracy: 0.7343
# Epoch 42/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0918 - accuracy: 0.9758 - val_loss: 1.1497 - val_accuracy: 0.7246
# Epoch 43/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0689 - accuracy: 0.9830 - val_loss: 1.0642 - val_accuracy: 0.7488
# Epoch 44/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0494 - accuracy: 0.9903 - val_loss: 1.1236 - val_accuracy: 0.7585
# Epoch 45/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0474 - accuracy: 0.9879 - val_loss: 1.1759 - val_accuracy: 0.7440
# Epoch 46/100
# 26/26 [==============================] - 0s 19ms/step - loss: 0.0543 - accuracy: 0.9855 - val_loss: 1.1240 - val_accuracy: 0.7536
# Epoch 47/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0457 - accuracy: 0.9891 - val_loss: 1.0533 - val_accuracy: 0.7536
# Epoch 48/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0542 - accuracy: 0.9867 - val_loss: 1.0971 - val_accuracy: 0.7633
# Epoch 49/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0377 - accuracy: 0.9891 - val_loss: 1.0618 - val_accuracy: 0.7681
# Epoch 50/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0250 - accuracy: 0.9964 - val_loss: 1.0723 - val_accuracy: 0.7681
# Epoch 51/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0251 - accuracy: 0.9964 - val_loss: 1.1035 - val_accuracy: 0.7585
# Epoch 52/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0240 - accuracy: 0.9952 - val_loss: 1.0515 - val_accuracy: 0.7633
# Epoch 53/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0238 - accuracy: 0.9952 - val_loss: 1.2401 - val_accuracy: 0.7246
# Epoch 54/100
# 26/26 [==============================] - 1s 20ms/step - loss: 0.0380 - accuracy: 0.9879 - val_loss: 1.0840 - val_accuracy: 0.7778
# Epoch 55/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0405 - accuracy: 0.9879 - val_loss: 1.2148 - val_accuracy: 0.7391
# Epoch 56/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0343 - accuracy: 0.9879 - val_loss: 1.1002 - val_accuracy: 0.7391
# Epoch 57/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0238 - accuracy: 0.9976 - val_loss: 1.1820 - val_accuracy: 0.7585
# Epoch 58/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0156 - accuracy: 0.9976 - val_loss: 1.2199 - val_accuracy: 0.7778
# Epoch 59/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0184 - accuracy: 0.9988 - val_loss: 1.2500 - val_accuracy: 0.7391
# Epoch 60/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0284 - accuracy: 0.9903 - val_loss: 1.2406 - val_accuracy: 0.7488
# Epoch 61/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0276 - accuracy: 0.9915 - val_loss: 1.1798 - val_accuracy: 0.7536
# Epoch 62/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0255 - accuracy: 0.9939 - val_loss: 1.2120 - val_accuracy: 0.7681
# Epoch 63/100
# 26/26 [==============================] - 1s 20ms/step - loss: 0.0243 - accuracy: 0.9964 - val_loss: 1.2415 - val_accuracy: 0.7585
# Epoch 64/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0344 - accuracy: 0.9915 - val_loss: 1.3274 - val_accuracy: 0.7391
# Epoch 65/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0330 - accuracy: 0.9879 - val_loss: 1.2577 - val_accuracy: 0.7681
# Epoch 66/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 1.2515 - val_accuracy: 0.7729
# Epoch 67/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0219 - accuracy: 0.9964 - val_loss: 1.0893 - val_accuracy: 0.7681
# Epoch 68/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0274 - accuracy: 0.9927 - val_loss: 1.1696 - val_accuracy: 0.7198
# Epoch 69/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0409 - accuracy: 0.9855 - val_loss: 1.1610 - val_accuracy: 0.7488
# Epoch 70/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0288 - accuracy: 0.9927 - val_loss: 1.2634 - val_accuracy: 0.7681
# Epoch 71/100
# 26/26 [==============================] - 1s 19ms/step - loss: 0.0464 - accuracy: 0.9891 - val_loss: 1.1997 - val_accuracy: 0.7681
# Epoch 72/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0326 - accuracy: 0.9879 - val_loss: 1.1588 - val_accuracy: 0.7488
# Epoch 73/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.1373 - val_accuracy: 0.7391
# Epoch 74/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0163 - accuracy: 0.9952 - val_loss: 1.2261 - val_accuracy: 0.7488
# Epoch 75/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0297 - accuracy: 0.9915 - val_loss: 1.2809 - val_accuracy: 0.7440
# Epoch 76/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0533 - accuracy: 0.9842 - val_loss: 1.1577 - val_accuracy: 0.7343
# Epoch 77/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0240 - accuracy: 0.9915 - val_loss: 1.2363 - val_accuracy: 0.7778
# Epoch 78/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0244 - accuracy: 0.9903 - val_loss: 1.5388 - val_accuracy: 0.7343
# Epoch 79/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0272 - accuracy: 0.9927 - val_loss: 1.2257 - val_accuracy: 0.7295
# Epoch 80/100
# 26/26 [==============================] - 1s 20ms/step - loss: 0.0372 - accuracy: 0.9891 - val_loss: 1.1594 - val_accuracy: 0.7729
# Epoch 81/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0246 - accuracy: 0.9952 - val_loss: 1.1014 - val_accuracy: 0.7826
# Epoch 82/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0125 - accuracy: 0.9988 - val_loss: 1.1347 - val_accuracy: 0.7488
# Epoch 83/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0184 - accuracy: 0.9952 - val_loss: 1.3332 - val_accuracy: 0.7488
# Epoch 84/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0273 - accuracy: 0.9952 - val_loss: 1.2883 - val_accuracy: 0.7633
# Epoch 85/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0091 - accuracy: 0.9988 - val_loss: 1.2213 - val_accuracy: 0.7681
# Epoch 86/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0102 - accuracy: 0.9976 - val_loss: 1.2586 - val_accuracy: 0.7729
# Epoch 87/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 1.2056 - val_accuracy: 0.7874
# Epoch 88/100
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0182 - accuracy: 0.9952 - val_loss: 1.2275 - val_accuracy: 0.7391
# Epoch 89/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0282 - accuracy: 0.9891 - val_loss: 1.2294 - val_accuracy: 0.7440
# Epoch 90/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0571 - accuracy: 0.9782 - val_loss: 1.3427 - val_accuracy: 0.7536
# Epoch 91/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0304 - accuracy: 0.9903 - val_loss: 1.3030 - val_accuracy: 0.7488
# Epoch 92/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0380 - accuracy: 0.9879 - val_loss: 1.2108 - val_accuracy: 0.7295
# Epoch 93/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 1.3025 - val_accuracy: 0.7585
# Epoch 94/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 0.9964 - val_loss: 1.3980 - val_accuracy: 0.7391
# Epoch 95/100
# 26/26 [==============================] - 1s 20ms/step - loss: 0.0169 - accuracy: 0.9952 - val_loss: 1.3282 - val_accuracy: 0.7440
# Epoch 96/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0147 - accuracy: 0.9976 - val_loss: 1.3379 - val_accuracy: 0.7488
# Epoch 97/100
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0283 - accuracy: 0.9915 - val_loss: 1.2695 - val_accuracy: 0.7729
# Epoch 98/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0088 - accuracy: 0.9988 - val_loss: 1.2160 - val_accuracy: 0.7633
# Epoch 99/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 1.3690 - val_accuracy: 0.7633
# Epoch 100/100
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0154 - accuracy: 0.9939 - val_loss: 1.2580 - val_accuracy: 0.7778
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2580 - accuracy: 0.7778
# Test loss: 1.2579796314239502
# Test accuracy: 0.7777777910232544

# %%
print("Accuracy of our model on test data : " , model.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2580 - accuracy: 0.7778
# Accuracy of our model on test data :  77.77777910232544 %

# %%
# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Get the predicted labels for the test set
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)  # Convert one-hot encoded predictions to labels

# Convert the true labels from one-hot encoding to labels
y_true_labels = np.argmax(y_test, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)

class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad','surprise']  # Replace with your actual class names
report = classification_report(y_true_labels, y_pred_labels, target_names=class_names, labels=range(len(class_names)))

# Display the confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
print(report)
# Out:
# 7/7 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#        angry       0.84      0.79      0.81        33
#      disgust       0.62      0.80      0.70        25
#         fear       0.75      0.71      0.73        34
#        happy       0.78      0.64      0.71        28
#      neutral       0.92      1.00      0.96        23
#          sad       0.84      0.90      0.87        30
#     surprise       0.72      0.68      0.70        34
#
#     accuracy                           0.78       207
#    macro avg       0.78      0.79      0.78       207
# weighted avg       0.78      0.78      0.78       207

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.97      1.00      0.98        91
#      disgust       0.00      0.00      0.00         0
#         fear       1.00      1.00      1.00        89
#        happy       1.00      0.97      0.98        92
#      neutral       1.00      1.00      1.00        80
#          sad       1.00      1.00      1.00        97
#     surprise       1.00      1.00      1.00        81
#
#    micro avg       0.99      0.99      0.99       530
#    macro avg       0.85      0.85      0.85       530
# weighted avg       0.99      0.99      0.99       530

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0188 - accuracy: 0.9924 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 2/100
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0218 - accuracy: 0.9939 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 3/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 4/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 5/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 6/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 7/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 8/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0202 - accuracy: 0.9894 - val_loss: 0.0115 - val_accuracy: 0.9939
# Epoch 9/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0336 - accuracy: 0.9924 - val_loss: 0.0152 - val_accuracy: 0.9939
# Epoch 10/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0178 - accuracy: 0.9970 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 11/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 12/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0109 - accuracy: 0.9985 - val_loss: 0.0251 - val_accuracy: 0.9939
# Epoch 13/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0225 - accuracy: 0.9939 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 14/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 7.7654e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0553 - accuracy: 0.9864 - val_loss: 0.0545 - val_accuracy: 0.9818
# Epoch 16/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0638 - accuracy: 0.9758 - val_loss: 0.0317 - val_accuracy: 0.9818
# Epoch 17/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.1129 - accuracy: 0.9621 - val_loss: 0.0254 - val_accuracy: 0.9939
# Epoch 18/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0804 - accuracy: 0.9697 - val_loss: 0.0566 - val_accuracy: 0.9939
# Epoch 19/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0959 - accuracy: 0.9652 - val_loss: 0.3245 - val_accuracy: 0.9455
# Epoch 20/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0765 - accuracy: 0.9773 - val_loss: 0.0515 - val_accuracy: 0.9818
# Epoch 21/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0478 - accuracy: 0.9848 - val_loss: 0.1830 - val_accuracy: 0.9394
# Epoch 22/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0737 - accuracy: 0.9773 - val_loss: 0.0656 - val_accuracy: 0.9697
# Epoch 23/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0634 - accuracy: 0.9818 - val_loss: 0.0717 - val_accuracy: 0.9818
# Epoch 24/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0394 - accuracy: 0.9833 - val_loss: 0.0741 - val_accuracy: 0.9758
# Epoch 25/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0416 - accuracy: 0.9848 - val_loss: 0.0951 - val_accuracy: 0.9697
# Epoch 26/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0308 - accuracy: 0.9909 - val_loss: 0.1063 - val_accuracy: 0.9576
# Epoch 27/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0407 - accuracy: 0.9864 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 28/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0218 - accuracy: 0.9894 - val_loss: 0.0284 - val_accuracy: 0.9939
# Epoch 29/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0261 - accuracy: 0.9894 - val_loss: 0.0500 - val_accuracy: 0.9818
# Epoch 30/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0264 - accuracy: 0.9939 - val_loss: 0.0786 - val_accuracy: 0.9758
# Epoch 31/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0128 - accuracy: 0.9970 - val_loss: 0.1432 - val_accuracy: 0.9576
# Epoch 32/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0192 - accuracy: 0.9909 - val_loss: 0.0668 - val_accuracy: 0.9697
# Epoch 33/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0152 - accuracy: 0.9970 - val_loss: 0.0357 - val_accuracy: 0.9818
# Epoch 34/100
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0144 - accuracy: 0.9939 - val_loss: 0.0764 - val_accuracy: 0.9818
# Epoch 35/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 36/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.0196 - val_accuracy: 0.9939
# Epoch 37/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9939
# Epoch 38/100
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0053 - accuracy: 0.9970 - val_loss: 0.0283 - val_accuracy: 0.9879
# Epoch 39/100
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9939
# Epoch 40/100
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9939
# Epoch 41/100
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9939
# Epoch 42/100
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0180 - accuracy: 0.9970 - val_loss: 0.0446 - val_accuracy: 0.9818
# Epoch 43/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0117 - accuracy: 0.9970 - val_loss: 0.0402 - val_accuracy: 0.9879
# Epoch 44/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0604 - val_accuracy: 0.9879
# Epoch 45/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.0386 - val_accuracy: 0.9879
# Epoch 46/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0622 - val_accuracy: 0.9879
# Epoch 47/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9879
# Epoch 48/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9879
# Epoch 49/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.0331 - val_accuracy: 0.9879
# Epoch 50/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9939
# Epoch 51/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0063 - accuracy: 0.9970 - val_loss: 0.0356 - val_accuracy: 0.9818
# Epoch 52/100
# 21/21 [==============================] - 1s 28ms/step - loss: 0.0260 - accuracy: 0.9939 - val_loss: 0.1017 - val_accuracy: 0.9697
# Epoch 53/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0090 - accuracy: 0.9955 - val_loss: 0.0634 - val_accuracy: 0.9758
# Epoch 54/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.0921 - val_accuracy: 0.9697
# Epoch 55/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0095 - accuracy: 0.9955 - val_loss: 0.1117 - val_accuracy: 0.9515
# Epoch 56/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.0481 - val_accuracy: 0.9818
# Epoch 57/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0445 - accuracy: 0.9848 - val_loss: 0.2331 - val_accuracy: 0.9152
# Epoch 58/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0291 - accuracy: 0.9894 - val_loss: 0.2184 - val_accuracy: 0.9636
# Epoch 59/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0386 - accuracy: 0.9879 - val_loss: 0.1041 - val_accuracy: 0.9636
# Epoch 60/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0327 - accuracy: 0.9909 - val_loss: 0.0731 - val_accuracy: 0.9636
# Epoch 61/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0226 - accuracy: 0.9939 - val_loss: 0.0721 - val_accuracy: 0.9758
# Epoch 62/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.1337 - val_accuracy: 0.9455
# Epoch 63/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0158 - accuracy: 0.9939 - val_loss: 0.1375 - val_accuracy: 0.9576
# Epoch 64/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9576
# Epoch 65/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0131 - accuracy: 0.9985 - val_loss: 0.0819 - val_accuracy: 0.9758
# Epoch 66/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0179 - accuracy: 0.9924 - val_loss: 0.0466 - val_accuracy: 0.9758
# Epoch 67/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.1996 - val_accuracy: 0.9394
# Epoch 68/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0189 - accuracy: 0.9955 - val_loss: 0.0717 - val_accuracy: 0.9818
# Epoch 69/100
# 21/21 [==============================] - 1s 27ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.0642 - val_accuracy: 0.9879
# Epoch 70/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.1283 - val_accuracy: 0.9697
# Epoch 71/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.2290 - val_accuracy: 0.9697
# Epoch 72/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0133 - accuracy: 0.9985 - val_loss: 0.1006 - val_accuracy: 0.9636
# Epoch 73/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9697
# Epoch 74/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9576
# Epoch 75/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.1008 - val_accuracy: 0.9758
# Epoch 76/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0030 - accuracy: 0.9985 - val_loss: 0.1167 - val_accuracy: 0.9697
# Epoch 77/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 0.0934 - val_accuracy: 0.9636
# Epoch 78/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 0.9818
# Epoch 79/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9879
# Epoch 80/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9697
# Epoch 81/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 0.0751 - val_accuracy: 0.9818
# Epoch 82/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 0.9985 - val_loss: 0.0822 - val_accuracy: 0.9939
# Epoch 83/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0854 - val_accuracy: 0.9818
# Epoch 84/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9879
# Epoch 85/100
# 21/21 [==============================] - 0s 23ms/step - loss: 9.8533e-04 - accuracy: 1.0000 - val_loss: 0.1140 - val_accuracy: 0.9879
# Epoch 86/100
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9879
# Epoch 87/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0138 - accuracy: 0.9970 - val_loss: 0.1000 - val_accuracy: 0.9879
# Epoch 88/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.1444 - val_accuracy: 0.9636
# Epoch 89/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0248 - accuracy: 0.9939 - val_loss: 0.1607 - val_accuracy: 0.9697
# Epoch 90/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0512 - accuracy: 0.9879 - val_loss: 0.2628 - val_accuracy: 0.9455
# Epoch 91/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0421 - accuracy: 0.9864 - val_loss: 0.2875 - val_accuracy: 0.9273
# Epoch 92/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0368 - accuracy: 0.9833 - val_loss: 0.2208 - val_accuracy: 0.9273
# Epoch 93/100
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0279 - accuracy: 0.9909 - val_loss: 0.2970 - val_accuracy: 0.9333
# Epoch 94/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0615 - accuracy: 0.9833 - val_loss: 0.3706 - val_accuracy: 0.9455
# Epoch 95/100
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0689 - accuracy: 0.9773 - val_loss: 0.3588 - val_accuracy: 0.9333
# Epoch 96/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0415 - accuracy: 0.9909 - val_loss: 0.1306 - val_accuracy: 0.9697
# Epoch 97/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.1962 - val_accuracy: 0.9576
# Epoch 98/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0592 - accuracy: 0.9848 - val_loss: 0.2893 - val_accuracy: 0.9273
# Epoch 99/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0275 - accuracy: 0.9924 - val_loss: 0.3207 - val_accuracy: 0.9212
# Epoch 100/100
# 21/21 [==============================] - 0s 24ms/step - loss: 0.0275 - accuracy: 0.9909 - val_loss: 0.2454 - val_accuracy: 0.9394

# %%
print("Accuracy of our model on train data : " , model.evaluate(X_train,y_train)[1]*100 , "%")
# Out:
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0505 - accuracy: 0.9879
# Accuracy of our model on train data :  98.78787994384766 %

# %%
model.save('audio_emotion.h5')
