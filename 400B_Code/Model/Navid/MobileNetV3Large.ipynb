# %% [markdown]
# # Data Importing

# %%
#Import The required Python libraries.
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import os
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from skimage import io, transform
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, EarlyStopping,CSVLogger,ProgbarLogger
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D, BatchNormalization
from keras.regularizers import l2
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# **Changable_Parameter**

# %%
#here image size is 256x256
IMAGE_SIZE = 128
#every time process 32 images (61x31)~1951
BATCH_SIZE = 32
#how many color have in these pictures
CHANNELS = 3
#80x25~1951
EPOCHS = 100
NUM_CLASSES = 7
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
patience=10
data_dir ="E:\\Capstone\\Dataset\\Gray_Img\\images"

model_name="DenseNet121"

# %%
import tensorflow as tf



# Define image parameters
img_height = IMAGE_SIZE
img_width = img_height
batch_size = BATCH_SIZE

# Define data augmentation parameters
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2 , # 20% of the data will be used for validation
    rotation_range=5,  # Rotate images randomly up to 20 degrees
    # Zoom range [1-zoom_range, 1+zoom_range]
    #horizontal_flip=True,  # Flip images horizontally
    #vertical_flip=True  # Flip images vertically
     # Strategy used for filling in newly created pixels
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # shear_range=0.2,
    # zoom_range=0.2,
    horizontal_flip=True,
    # vertical_flip=True,
    fill_mode='nearest'
)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',  # Update for multi-class classification
    subset='training'  # specify that this generator will be used for training data
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',  # Update for multi-class classification
    subset='validation'  # specify that this generator will be used for validation data
)
# Out:
# Found 16126 images belonging to 7 classes.
# Found 4031 images belonging to 7 classes.

# %%
images, labels = next(train_generator)

# Plot four random images from the batch
fig, axes = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    # Generate a random index
    random_index = np.random.randint(0, BATCH_SIZE)
    
    # Plot the image
    axes[i].imshow(images[random_index])
    
    # Get the corresponding label
    label = labels[random_index]
    
    # Set the title as the class name
    class_name = train_generator.class_indices
    axes[i].set_title(list(class_name.keys())[np.argmax(label)])

plt.show()

# %% [markdown]
# # Building model

# %%
from tensorflow.keras.applications import EfficientNetV2B0,ResNet50,InceptionV3,NASNetMobile,EfficientNetV2L,MobileNetV3Large

model= MobileNetV3Large(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3),
                 include_preprocessing=True
                 )

# Here we freeze the last 4 layers 
# Layers are set to trainable as True by default
for layer in model.layers:
    layer.trainable = False
    
# Let's print our layers 
for (i,layer) in enumerate(model.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 21s 2us/step
# 0 InputLayer False
# 1 Rescaling False
# 2 Conv2D False
# 3 BatchNormalization False
# 4 TFOpLambda False
# 5 ReLU False
# 6 TFOpLambda False
# 7 Multiply False
# 8 DepthwiseConv2D False
# 9 BatchNormalization False
# 10 ReLU False
# 11 Conv2D False
# 12 BatchNormalization False
# 13 Add False
# 14 Conv2D False
# 15 BatchNormalization False
# 16 ReLU False
# 17 ZeroPadding2D False
# 18 DepthwiseConv2D False
# 19 BatchNormalization False
# 20 ReLU False
# 21 Conv2D False
# 22 BatchNormalization False
# 23 Conv2D False
# 24 BatchNormalization False
# 25 ReLU False
# 26 DepthwiseConv2D False
# 27 BatchNormalization False
# 28 ReLU False
# 29 Conv2D False
# 30 BatchNormalization False
# 31 Add False
# 32 Conv2D False
# 33 BatchNormalization False
# 34 ReLU False
# 35 ZeroPadding2D False
# 36 DepthwiseConv2D False
# 37 BatchNormalization False
# 38 ReLU False
# 39 GlobalAveragePooling2D False
# 40 Conv2D False
# 41 ReLU False
# 42 Conv2D False
# 43 TFOpLambda False
# 44 ReLU False
# 45 TFOpLambda False
# 46 Multiply False
# 47 Conv2D False
# 48 BatchNormalization False
# 49 Conv2D False
# 50 BatchNormalization False
# 51 ReLU False
# 52 DepthwiseConv2D False
# 53 BatchNormalization False
# 54 ReLU False
# 55 GlobalAveragePooling2D False
# 56 Conv2D False
# 57 ReLU False
# 58 Conv2D False
# 59 TFOpLambda False
# 60 ReLU False
# 61 TFOpLambda False
# 62 Multiply False
# 63 Conv2D False
# 64 BatchNormalization False
# 65 Add False
# 66 Conv2D False
# 67 BatchNormalization False
# 68 ReLU False
# 69 DepthwiseConv2D False
# 70 BatchNormalization False
# 71 ReLU False
# 72 GlobalAveragePooling2D False
# 73 Conv2D False
# 74 ReLU False
# 75 Conv2D False
# 76 TFOpLambda False
# 77 ReLU False
# 78 TFOpLambda False
# 79 Multiply False
# 80 Conv2D False
# 81 BatchNormalization False
# 82 Add False
# 83 Conv2D False
# 84 BatchNormalization False
# 85 TFOpLambda False
# 86 ReLU False
# 87 TFOpLambda False
# 88 Multiply False
# 89 ZeroPadding2D False
# 90 DepthwiseConv2D False
# 91 BatchNormalization False
# 92 TFOpLambda False
# 93 ReLU False
# 94 TFOpLambda False
# 95 Multiply False
# 96 Conv2D False
# 97 BatchNormalization False
# 98 Conv2D False
# 99 BatchNormalization False
# 100 TFOpLambda False
# 101 ReLU False
# 102 TFOpLambda False
# 103 Multiply False
# 104 DepthwiseConv2D False
# 105 BatchNormalization False
# 106 TFOpLambda False
# 107 ReLU False
# 108 TFOpLambda False
# 109 Multiply False
# 110 Conv2D False
# 111 BatchNormalization False
# 112 Add False
# 113 Conv2D False
# 114 BatchNormalization False
# 115 TFOpLambda False
# 116 ReLU False
# 117 TFOpLambda False
# 118 Multiply False
# 119 DepthwiseConv2D False
# 120 BatchNormalization False
# 121 TFOpLambda False
# 122 ReLU False
# 123 TFOpLambda False
# 124 Multiply False
# 125 Conv2D False
# 126 BatchNormalization False
# 127 Add False
# 128 Conv2D False
# 129 BatchNormalization False
# 130 TFOpLambda False
# 131 ReLU False
# 132 TFOpLambda False
# 133 Multiply False
# 134 DepthwiseConv2D False
# 135 BatchNormalization False
# 136 TFOpLambda False
# 137 ReLU False
# 138 TFOpLambda False
# 139 Multiply False
# 140 Conv2D False
# 141 BatchNormalization False
# 142 Add False
# 143 Conv2D False
# 144 BatchNormalization False
# 145 TFOpLambda False
# 146 ReLU False
# 147 TFOpLambda False
# 148 Multiply False
# 149 DepthwiseConv2D False
# 150 BatchNormalization False
# 151 TFOpLambda False
# 152 ReLU False
# 153 TFOpLambda False
# 154 Multiply False
# 155 GlobalAveragePooling2D False
# 156 Conv2D False
# 157 ReLU False
# 158 Conv2D False
# 159 TFOpLambda False
# 160 ReLU False
# 161 TFOpLambda False
# 162 Multiply False
# 163 Conv2D False
# 164 BatchNormalization False
# 165 Conv2D False
# 166 BatchNormalization False
# 167 TFOpLambda False
# 168 ReLU False
# 169 TFOpLambda False
# 170 Multiply False
# 171 DepthwiseConv2D False
# 172 BatchNormalization False
# 173 TFOpLambda False
# 174 ReLU False
# 175 TFOpLambda False
# 176 Multiply False
# 177 GlobalAveragePooling2D False
# 178 Conv2D False
# 179 ReLU False
# 180 Conv2D False
# 181 TFOpLambda False
# 182 ReLU False
# 183 TFOpLambda False
# 184 Multiply False
# 185 Conv2D False
# 186 BatchNormalization False
# 187 Add False
# 188 Conv2D False
# 189 BatchNormalization False
# 190 TFOpLambda False
# 191 ReLU False
# 192 TFOpLambda False
# 193 Multiply False
# 194 ZeroPadding2D False
# 195 DepthwiseConv2D False
# 196 BatchNormalization False
# 197 TFOpLambda False
# 198 ReLU False
# 199 TFOpLambda False
# 200 Multiply False
# 201 GlobalAveragePooling2D False
# 202 Conv2D False
# 203 ReLU False
# 204 Conv2D False
# 205 TFOpLambda False
# 206 ReLU False
# 207 TFOpLambda False
# 208 Multiply False
# 209 Conv2D False
# 210 BatchNormalization False
# 211 Conv2D False
# 212 BatchNormalization False
# 213 TFOpLambda False
# 214 ReLU False
# 215 TFOpLambda False
# 216 Multiply False
# 217 DepthwiseConv2D False
# 218 BatchNormalization False
# 219 TFOpLambda False
# 220 ReLU False
# 221 TFOpLambda False
# 222 Multiply False
# 223 GlobalAveragePooling2D False
# 224 Conv2D False
# 225 ReLU False
# 226 Conv2D False
# 227 TFOpLambda False
# 228 ReLU False
# 229 TFOpLambda False
# 230 Multiply False
# 231 Conv2D False
# 232 BatchNormalization False
# 233 Add False
# 234 Conv2D False
# 235 BatchNormalization False
# 236 TFOpLambda False
# 237 ReLU False
# 238 TFOpLambda False
# 239 Multiply False
# 240 DepthwiseConv2D False
# 241 BatchNormalization False
# 242 TFOpLambda False
# 243 ReLU False
# 244 TFOpLambda False
# 245 Multiply False
# 246 GlobalAveragePooling2D False
# 247 Conv2D False
# 248 ReLU False
# 249 Conv2D False
# 250 TFOpLambda False
# 251 ReLU False
# 252 TFOpLambda False
# 253 Multiply False
# 254 Conv2D False
# 255 BatchNormalization False
# 256 Add False
# 257 Conv2D False
# 258 BatchNormalization False
# 259 TFOpLambda False
# 260 ReLU False
# 261 TFOpLambda False
# 262 Multiply False

# %% [markdown]
# **Fine Tuning**

# %%
# # for layer in model.layers[:260]:
# #    layer.trainable = False
# # for layer in model.layers[260:]:
# #    layer.trainable = True

# # print('Last block of the conv_base is now trainable')


# for i, layer in enumerate(model.layers):
#    print(i, layer.name, layer.trainable)

# %%
def lw(bottom_model, num_classes):
    """creates the top or head of the model that will be 
    placed on top of the bottom layers"""

    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation='relu')(top_model)  # Adding L2 regularization
    # top_model = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(top_model)  # You can add regularization to more layers if needed
    # top_model = BatchNormalization()(top_model)
    top_model = Dropout(0.5)(top_model) 
    #top_model = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(top_model)  # Adding L2 regularization
    # top_model = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(top_model)  # You can add regularization to more layers if needed
    # top_model = BatchNormalization()(top_model)
    #top_model = Dropout(0.5)(top_model) 
    top_model = Dense(num_classes, activation='softmax')(top_model)
    return top_model

# %%
from keras.models import Model
FC_Head = lw(model, NUM_CLASSES)
model = Model(inputs = model.input, outputs = FC_Head)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 128, 128, 3)          0         ['input_1[0][0]']
#
#  Conv (Conv2D)               (None, 64, 64, 16)           432       ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 64, 64, 16)           64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add (TFOp  (None, 64, 64, 16)           0         ['Conv/BatchNorm[0][0]']
#  Lambda)
#
#  re_lu (ReLU)                (None, 64, 64, 16)           0         ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 64, 64, 16)           0         ['re_lu[0][0]']
#  da)
#
#  multiply (Multiply)         (None, 64, 64, 16)           0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (D  (None, 64, 64, 16)           144       ['multiply[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv/depthwise/Ba  (None, 64, 64, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_1 (ReLU)              (None, 64, 64, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/project (Con  (None, 64, 64, 16)           256       ['re_lu_1[0][0]']
#  v2D)
#
#  expanded_conv/project/Batc  (None, 64, 64, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv/Add (Add)     (None, 64, 64, 16)           0         ['multiply[0][0]',
#                                                                      'expanded_conv/project/BatchN
#                                                                     orm[0][0]']
#
#  expanded_conv_1/expand (Co  (None, 64, 64, 64)           1024      ['expanded_conv/Add[0][0]']
#  nv2D)
#
#  expanded_conv_1/expand/Bat  (None, 64, 64, 64)           256       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_2 (ReLU)              (None, 64, 64, 64)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 65, 65, 64)           0         ['re_lu_2[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 32, 32, 64)           576       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 32, 32, 64)           256       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_3 (ReLU)              (None, 32, 32, 64)           0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 32, 32, 24)           1536      ['re_lu_3[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 32, 32, 24)           96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 32, 32, 72)           1728      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 32, 32, 72)           288       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_4 (ReLU)              (None, 32, 32, 72)           0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 32, 32, 72)           648       ['re_lu_4[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 32, 32, 72)           288       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_5 (ReLU)              (None, 32, 32, 72)           0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 32, 32, 24)           1728      ['re_lu_5[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 32, 32, 24)           96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 32, 32, 24)           0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 32, 32, 72)           1728      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 32, 32, 72)           288       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_6 (ReLU)              (None, 32, 32, 72)           0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 35, 35, 72)           0         ['re_lu_6[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 16, 16, 72)           1800      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 16, 16, 72)           288       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_7 (ReLU)              (None, 16, 16, 72)           0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             0         ['re_lu_7[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             1752      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             1800      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 1, 1, 72)             0         ['expanded_conv_3/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_8 (ReLU)              (None, 1, 1, 72)             0         ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.math.multiply_1 (TFOpLa  (None, 1, 1, 72)             0         ['re_lu_8[0][0]']
#  mbda)
#
#  expanded_conv_3/squeeze_ex  (None, 16, 16, 72)           0         ['re_lu_7[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (C  (None, 16, 16, 40)           2880      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 16, 16, 40)           160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 16, 16, 120)          4800      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 16, 16, 120)          480       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_9 (ReLU)              (None, 16, 16, 120)          0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_4/depthwise   (None, 16, 16, 120)          3000      ['re_lu_9[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 16, 16, 120)          480       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_10 (ReLU)             (None, 16, 16, 120)          0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_10[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 1, 1, 120)            0         ['expanded_conv_4/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_11 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  tf.math.multiply_2 (TFOpLa  (None, 1, 1, 120)            0         ['re_lu_11[0][0]']
#  mbda)
#
#  expanded_conv_4/squeeze_ex  (None, 16, 16, 120)          0         ['re_lu_10[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (C  (None, 16, 16, 40)           4800      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 16, 16, 40)           160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 16, 16, 40)           0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 16, 16, 120)          4800      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 16, 16, 120)          480       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_12 (ReLU)             (None, 16, 16, 120)          0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_5/depthwise   (None, 16, 16, 120)          3000      ['re_lu_12[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 16, 16, 120)          480       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_13 (ReLU)             (None, 16, 16, 120)          0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_13[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 1, 1, 120)            0         ['expanded_conv_5/squeeze_exci
#  OpLambda)                                                          te/Conv_1[0][0]']
#
#  re_lu_14 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  tf.math.multiply_3 (TFOpLa  (None, 1, 1, 120)            0         ['re_lu_14[0][0]']
#  mbda)
#
#  expanded_conv_5/squeeze_ex  (None, 16, 16, 120)          0         ['re_lu_13[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (C  (None, 16, 16, 40)           4800      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 16, 16, 40)           160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 16, 16, 40)           0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 16, 16, 240)          9600      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 16, 16, 240)          960       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_4 (TF  (None, 16, 16, 240)          0         ['expanded_conv_6/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_15 (ReLU)             (None, 16, 16, 240)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  tf.math.multiply_4 (TFOpLa  (None, 16, 16, 240)          0         ['re_lu_15[0][0]']
#  mbda)
#
#  multiply_1 (Multiply)       (None, 16, 16, 240)          0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 17, 17, 240)          0         ['multiply_1[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_6/depthwise   (None, 8, 8, 240)            2160      ['expanded_conv_6/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 8, 8, 240)            960       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_5 (TF  (None, 8, 8, 240)            0         ['expanded_conv_6/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_16 (ReLU)             (None, 8, 8, 240)            0         ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  tf.math.multiply_5 (TFOpLa  (None, 8, 8, 240)            0         ['re_lu_16[0][0]']
#  mbda)
#
#  multiply_2 (Multiply)       (None, 8, 8, 240)            0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (C  (None, 8, 8, 80)             19200     ['multiply_2[0][0]']
#  onv2D)
#
#  expanded_conv_6/project/Ba  (None, 8, 8, 80)             320       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 8, 8, 200)            16000     ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 8, 8, 200)            800       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_6 (TF  (None, 8, 8, 200)            0         ['expanded_conv_7/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_17 (ReLU)             (None, 8, 8, 200)            0         ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  tf.math.multiply_6 (TFOpLa  (None, 8, 8, 200)            0         ['re_lu_17[0][0]']
#  mbda)
#
#  multiply_3 (Multiply)       (None, 8, 8, 200)            0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise   (None, 8, 8, 200)            1800      ['multiply_3[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 8, 8, 200)            800       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_7 (TF  (None, 8, 8, 200)            0         ['expanded_conv_7/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_18 (ReLU)             (None, 8, 8, 200)            0         ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  tf.math.multiply_7 (TFOpLa  (None, 8, 8, 200)            0         ['re_lu_18[0][0]']
#  mbda)
#
#  multiply_4 (Multiply)       (None, 8, 8, 200)            0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (C  (None, 8, 8, 80)             16000     ['multiply_4[0][0]']
#  onv2D)
#
#  expanded_conv_7/project/Ba  (None, 8, 8, 80)             320       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, 8, 8, 80)             0         ['expanded_conv_6/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_7/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_8/expand (Co  (None, 8, 8, 184)            14720     ['expanded_conv_7/Add[0][0]']
#  nv2D)
#
#  expanded_conv_8/expand/Bat  (None, 8, 8, 184)            736       ['expanded_conv_8/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_8 (TF  (None, 8, 8, 184)            0         ['expanded_conv_8/expand/Batch
#  OpLambda)                                                          Norm[0][0]']
#
#  re_lu_19 (ReLU)             (None, 8, 8, 184)            0         ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  tf.math.multiply_8 (TFOpLa  (None, 8, 8, 184)            0         ['re_lu_19[0][0]']
#  mbda)
#
#  multiply_5 (Multiply)       (None, 8, 8, 184)            0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise   (None, 8, 8, 184)            1656      ['multiply_5[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_8/depthwise/  (None, 8, 8, 184)            736       ['expanded_conv_8/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_9 (TF  (None, 8, 8, 184)            0         ['expanded_conv_8/depthwise/Ba
#  OpLambda)                                                          tchNorm[0][0]']
#
#  re_lu_20 (ReLU)             (None, 8, 8, 184)            0         ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  tf.math.multiply_9 (TFOpLa  (None, 8, 8, 184)            0         ['re_lu_20[0][0]']
#  mbda)
#
#  multiply_6 (Multiply)       (None, 8, 8, 184)            0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (C  (None, 8, 8, 80)             14720     ['multiply_6[0][0]']
#  onv2D)
#
#  expanded_conv_8/project/Ba  (None, 8, 8, 80)             320       ['expanded_conv_8/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_8/Add (Add)   (None, 8, 8, 80)             0         ['expanded_conv_7/Add[0][0]',
#                                                                      'expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_9/expand (Co  (None, 8, 8, 184)            14720     ['expanded_conv_8/Add[0][0]']
#  nv2D)
#
#  expanded_conv_9/expand/Bat  (None, 8, 8, 184)            736       ['expanded_conv_9/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_10 (T  (None, 8, 8, 184)            0         ['expanded_conv_9/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_21 (ReLU)             (None, 8, 8, 184)            0         ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.multiply_10 (TFOpL  (None, 8, 8, 184)            0         ['re_lu_21[0][0]']
#  ambda)
#
#  multiply_7 (Multiply)       (None, 8, 8, 184)            0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise   (None, 8, 8, 184)            1656      ['multiply_7[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 8, 8, 184)            736       ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_11 (T  (None, 8, 8, 184)            0         ['expanded_conv_9/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_22 (ReLU)             (None, 8, 8, 184)            0         ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  tf.math.multiply_11 (TFOpL  (None, 8, 8, 184)            0         ['re_lu_22[0][0]']
#  ambda)
#
#  multiply_8 (Multiply)       (None, 8, 8, 184)            0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (C  (None, 8, 8, 80)             14720     ['multiply_8[0][0]']
#  onv2D)
#
#  expanded_conv_9/project/Ba  (None, 8, 8, 80)             320       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 8, 8, 80)             0         ['expanded_conv_8/Add[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 8, 8, 480)            38400     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 8, 8, 480)            1920      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
# ...
#
#  expanded_conv_13/depthwise  (None, 4, 4, 960)            3840      ['expanded_conv_13/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_22 (T  (None, 4, 4, 960)            0         ['expanded_conv_13/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_33 (ReLU)             (None, 4, 4, 960)            0         ['tf.__operators__.add_22[0][0
#                                                                     ]']
#
#  tf.math.multiply_22 (TFOpL  (None, 4, 4, 960)            0         ['re_lu_33[0][0]']
#  ambda)
#
#  multiply_16 (Multiply)      (None, 4, 4, 960)            0         ['expanded_conv_13/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_22[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_16[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_13/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_13/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_13/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_23 (T  (None, 1, 1, 960)            0         ['expanded_conv_13/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_34 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_23[0][0
#                                                                     ]']
#
#  tf.math.multiply_23 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_34[0][0]']
#  ambda)
#
#  expanded_conv_13/squeeze_e  (None, 4, 4, 960)            0         ['multiply_16[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_23[0][0]']
#
#  expanded_conv_13/project (  (None, 4, 4, 160)            153600    ['expanded_conv_13/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_13/project/B  (None, 4, 4, 160)            640       ['expanded_conv_13/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_13/Add (Add)  (None, 4, 4, 160)            0         ['expanded_conv_12/project/Bat
#                                                                     chNorm[0][0]',
#                                                                      'expanded_conv_13/project/Bat
#                                                                     chNorm[0][0]']
#
#  expanded_conv_14/expand (C  (None, 4, 4, 960)            153600    ['expanded_conv_13/Add[0][0]']
#  onv2D)
#
#  expanded_conv_14/expand/Ba  (None, 4, 4, 960)            3840      ['expanded_conv_14/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.__operators__.add_24 (T  (None, 4, 4, 960)            0         ['expanded_conv_14/expand/Batc
#  FOpLambda)                                                         hNorm[0][0]']
#
#  re_lu_35 (ReLU)             (None, 4, 4, 960)            0         ['tf.__operators__.add_24[0][0
#                                                                     ]']
#
#  tf.math.multiply_24 (TFOpL  (None, 4, 4, 960)            0         ['re_lu_35[0][0]']
#  ambda)
#
#  multiply_17 (Multiply)      (None, 4, 4, 960)            0         ['expanded_conv_14/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_24[0][0]']
#
#  expanded_conv_14/depthwise  (None, 4, 4, 960)            24000     ['multiply_17[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_14/depthwise  (None, 4, 4, 960)            3840      ['expanded_conv_14/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_25 (T  (None, 4, 4, 960)            0         ['expanded_conv_14/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_36 (ReLU)             (None, 4, 4, 960)            0         ['tf.__operators__.add_25[0][0
#                                                                     ]']
#
#  tf.math.multiply_25 (TFOpL  (None, 4, 4, 960)            0         ['re_lu_36[0][0]']
#  ambda)
#
#  multiply_18 (Multiply)      (None, 4, 4, 960)            0         ['expanded_conv_14/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_25[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_18[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_14/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_14/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_14/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_26 (T  (None, 1, 1, 960)            0         ['expanded_conv_14/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_37 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_26[0][0
#                                                                     ]']
#
#  tf.math.multiply_26 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_37[0][0]']
#  ambda)
#
#  expanded_conv_14/squeeze_e  (None, 4, 4, 960)            0         ['multiply_18[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_26[0][0]']
#
#  expanded_conv_14/project (  (None, 4, 4, 160)            153600    ['expanded_conv_14/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_14/project/B  (None, 4, 4, 160)            640       ['expanded_conv_14/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_14/Add (Add)  (None, 4, 4, 160)            0         ['expanded_conv_13/Add[0][0]',
#                                                                      'expanded_conv_14/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 4, 4, 960)            153600    ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 4, 4, 960)            3840      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_27 (T  (None, 4, 4, 960)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_38 (ReLU)             (None, 4, 4, 960)            0         ['tf.__operators__.add_27[0][0
#                                                                     ]']
#
#  tf.math.multiply_27 (TFOpL  (None, 4, 4, 960)            0         ['re_lu_38[0][0]']
#  ambda)
#
#  multiply_19 (Multiply)      (None, 4, 4, 960)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_27[0][0]']
#
#  global_average_pooling2d (  (None, 960)                  0         ['multiply_19[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)                 984064    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    7175      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 3987591 (15.21 MB)
# Trainable params: 991239 (3.78 MB)
# Non-trainable params: 2996352 (11.43 MB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import LearningRateScheduler


def scheduler(epoch, lr):
     if epoch < 10:
         return lr
     else:
        return lr * np.exp(-0.1)

lr_scheduler = LearningRateScheduler(scheduler)

# %%
if not os.path.exists("Results"):
    os.makedirs("Results")
if not os.path.exists("Model"):
    os.makedirs("Model") 
csv_logger_path = os.path.join("Results", f"{model_name}_results.csv")
model_checkpoint_path = os.path.join("Model", f"{model_name}_Model.hdf5")

# %% [markdown]
# **CheckPoints**

# %%
csv_logger = CSVLogger(csv_logger_path)
early_stopping = EarlyStopping(monitor='val_loss', patience=patience)
check = ModelCheckpoint(model_checkpoint_path, verbose=1, save_best_only=True)
progbar_logger = ProgbarLogger()

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])
history = model.fit(train_generator,
                    epochs=EPOCHS, 
                    batch_size=BATCH_SIZE,
                    validation_data=validation_generator,
                    verbose = 1,
                    callbacks = [early_stopping,lr_scheduler,check,csv_logger],
                    initial_epoch=0)
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 504/504 [==============================] - ETA: 0s - loss: 1.9546 - accuracy: 0.1649
# Epoch 1: val_loss improved from inf to 1.93433, saving model to Model\DenseNet121_Model.hdf5
# c:\Python10\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 504/504 [==============================] - 314s 613ms/step - loss: 1.9546 - accuracy: 0.1649 - val_loss: 1.9343 - val_accuracy: 0.1977 - lr: 0.0010
# Epoch 2/100
# 504/504 [==============================] - ETA: 0s - loss: 1.9176 - accuracy: 0.1719
# Epoch 2: val_loss improved from 1.93433 to 1.92638, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 162s 321ms/step - loss: 1.9176 - accuracy: 0.1719 - val_loss: 1.9264 - val_accuracy: 0.1188 - lr: 0.0010
# Epoch 3/100
# 504/504 [==============================] - ETA: 0s - loss: 1.8913 - accuracy: 0.1904
# Epoch 3: val_loss improved from 1.92638 to 1.91591, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 156s 310ms/step - loss: 1.8913 - accuracy: 0.1904 - val_loss: 1.9159 - val_accuracy: 0.2047 - lr: 0.0010
# Epoch 4/100
# 504/504 [==============================] - ETA: 0s - loss: 1.8646 - accuracy: 0.2139
# Epoch 4: val_loss improved from 1.91591 to 1.91442, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 155s 308ms/step - loss: 1.8646 - accuracy: 0.2139 - val_loss: 1.9144 - val_accuracy: 0.1625 - lr: 0.0010
# Epoch 5/100
# 504/504 [==============================] - ETA: 0s - loss: 1.8435 - accuracy: 0.2161
# Epoch 5: val_loss improved from 1.91442 to 1.89170, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 150s 298ms/step - loss: 1.8435 - accuracy: 0.2161 - val_loss: 1.8917 - val_accuracy: 0.2191 - lr: 0.0010
# Epoch 6/100
# 504/504 [==============================] - ETA: 0s - loss: 1.8174 - accuracy: 0.2299
# Epoch 6: val_loss did not improve from 1.89170
# 504/504 [==============================] - 147s 292ms/step - loss: 1.8174 - accuracy: 0.2299 - val_loss: 1.8925 - val_accuracy: 0.1665 - lr: 0.0010
# Epoch 7/100
# 504/504 [==============================] - ETA: 0s - loss: 1.7979 - accuracy: 0.2438
# Epoch 7: val_loss improved from 1.89170 to 1.88429, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 141s 279ms/step - loss: 1.7979 - accuracy: 0.2438 - val_loss: 1.8843 - val_accuracy: 0.1625 - lr: 0.0010
# Epoch 8/100
# 504/504 [==============================] - ETA: 0s - loss: 1.7827 - accuracy: 0.2508
# Epoch 8: val_loss improved from 1.88429 to 1.88112, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 131s 260ms/step - loss: 1.7827 - accuracy: 0.2508 - val_loss: 1.8811 - val_accuracy: 0.1657 - lr: 0.0010
# Epoch 9/100
# 504/504 [==============================] - ETA: 0s - loss: 1.7684 - accuracy: 0.2613
# Epoch 9: val_loss improved from 1.88112 to 1.87612, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 145s 288ms/step - loss: 1.7684 - accuracy: 0.2613 - val_loss: 1.8761 - val_accuracy: 0.1826 - lr: 0.0010
# Epoch 10/100
# 504/504 [==============================] - ETA: 0s - loss: 1.7510 - accuracy: 0.2709
# Epoch 10: val_loss improved from 1.87612 to 1.87097, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 155s 308ms/step - loss: 1.7510 - accuracy: 0.2709 - val_loss: 1.8710 - val_accuracy: 0.1883 - lr: 0.0010
# Epoch 11/100
# 504/504 [==============================] - ETA: 0s - loss: 1.7364 - accuracy: 0.2753
# Epoch 11: val_loss improved from 1.87097 to 1.86389, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 152s 302ms/step - loss: 1.7364 - accuracy: 0.2753 - val_loss: 1.8639 - val_accuracy: 0.2126 - lr: 9.0484e-04
# Epoch 12/100
# 504/504 [==============================] - ETA: 0s - loss: 1.7199 - accuracy: 0.2889
# Epoch 12: val_loss improved from 1.86389 to 1.86047, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 154s 306ms/step - loss: 1.7199 - accuracy: 0.2889 - val_loss: 1.8605 - val_accuracy: 0.2362 - lr: 8.1873e-04
# Epoch 13/100
# 504/504 [==============================] - ETA: 0s - loss: 1.7094 - accuracy: 0.2887
# Epoch 13: val_loss did not improve from 1.86047
# 504/504 [==============================] - 136s 270ms/step - loss: 1.7094 - accuracy: 0.2887 - val_loss: 1.8692 - val_accuracy: 0.2101 - lr: 7.4082e-04
# Epoch 14/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6969 - accuracy: 0.2978
# Epoch 14: val_loss improved from 1.86047 to 1.84703, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 133s 263ms/step - loss: 1.6969 - accuracy: 0.2978 - val_loss: 1.8470 - val_accuracy: 0.2074 - lr: 6.7032e-04
# Epoch 15/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6891 - accuracy: 0.3001
# Epoch 15: val_loss did not improve from 1.84703
# 504/504 [==============================] - 129s 257ms/step - loss: 1.6891 - accuracy: 0.3001 - val_loss: 1.8591 - val_accuracy: 0.2009 - lr: 6.0653e-04
# Epoch 16/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6783 - accuracy: 0.3053
# Epoch 16: val_loss did not improve from 1.84703
# 504/504 [==============================] - 130s 258ms/step - loss: 1.6783 - accuracy: 0.3053 - val_loss: 1.8528 - val_accuracy: 0.2066 - lr: 5.4881e-04
# Epoch 17/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6686 - accuracy: 0.3111
# Epoch 17: val_loss did not improve from 1.84703
# 504/504 [==============================] - 129s 257ms/step - loss: 1.6686 - accuracy: 0.3111 - val_loss: 1.8690 - val_accuracy: 0.2084 - lr: 4.9659e-04
# Epoch 18/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6604 - accuracy: 0.3106
# Epoch 18: val_loss did not improve from 1.84703
# 504/504 [==============================] - 130s 257ms/step - loss: 1.6604 - accuracy: 0.3106 - val_loss: 1.8690 - val_accuracy: 0.2012 - lr: 4.4933e-04
# Epoch 19/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6552 - accuracy: 0.3161
# Epoch 19: val_loss did not improve from 1.84703
# 504/504 [==============================] - 130s 257ms/step - loss: 1.6552 - accuracy: 0.3161 - val_loss: 1.8670 - val_accuracy: 0.2220 - lr: 4.0657e-04
# Epoch 20/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6528 - accuracy: 0.3145
# Epoch 20: val_loss did not improve from 1.84703
# 504/504 [==============================] - 129s 256ms/step - loss: 1.6528 - accuracy: 0.3145 - val_loss: 1.8536 - val_accuracy: 0.2148 - lr: 3.6788e-04
# Epoch 21/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6443 - accuracy: 0.3209
# Epoch 21: val_loss did not improve from 1.84703
# 504/504 [==============================] - 130s 257ms/step - loss: 1.6443 - accuracy: 0.3209 - val_loss: 1.8602 - val_accuracy: 0.2166 - lr: 3.3287e-04
# Epoch 22/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6448 - accuracy: 0.3228
# Epoch 22: val_loss improved from 1.84703 to 1.84561, saving model to Model\DenseNet121_Model.hdf5
# 504/504 [==============================] - 150s 298ms/step - loss: 1.6448 - accuracy: 0.3228 - val_loss: 1.8456 - val_accuracy: 0.2121 - lr: 3.0119e-04
# Epoch 23/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6396 - accuracy: 0.3183
# Epoch 23: val_loss did not improve from 1.84561
# 504/504 [==============================] - 147s 291ms/step - loss: 1.6396 - accuracy: 0.3183 - val_loss: 1.8557 - val_accuracy: 0.2158 - lr: 2.7253e-04
# Epoch 24/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6348 - accuracy: 0.3246
# Epoch 24: val_loss did not improve from 1.84561
# 504/504 [==============================] - 143s 284ms/step - loss: 1.6348 - accuracy: 0.3246 - val_loss: 1.8488 - val_accuracy: 0.2235 - lr: 2.4660e-04
# Epoch 25/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6272 - accuracy: 0.3291
# Epoch 25: val_loss did not improve from 1.84561
# 504/504 [==============================] - 139s 275ms/step - loss: 1.6272 - accuracy: 0.3291 - val_loss: 1.8630 - val_accuracy: 0.2096 - lr: 2.2313e-04
# Epoch 26/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6217 - accuracy: 0.3277
# Epoch 26: val_loss did not improve from 1.84561
# 504/504 [==============================] - 151s 299ms/step - loss: 1.6217 - accuracy: 0.3277 - val_loss: 1.8583 - val_accuracy: 0.2235 - lr: 2.0190e-04
# Epoch 27/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6264 - accuracy: 0.3250
# Epoch 27: val_loss did not improve from 1.84561
# 504/504 [==============================] - 141s 279ms/step - loss: 1.6264 - accuracy: 0.3250 - val_loss: 1.8553 - val_accuracy: 0.2114 - lr: 1.8268e-04
# Epoch 28/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6214 - accuracy: 0.3303
# Epoch 28: val_loss did not improve from 1.84561
# 504/504 [==============================] - 138s 274ms/step - loss: 1.6214 - accuracy: 0.3303 - val_loss: 1.8538 - val_accuracy: 0.2210 - lr: 1.6530e-04
# Epoch 29/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6202 - accuracy: 0.3297
# Epoch 29: val_loss did not improve from 1.84561
# 504/504 [==============================] - 134s 266ms/step - loss: 1.6202 - accuracy: 0.3297 - val_loss: 1.8530 - val_accuracy: 0.2188 - lr: 1.4957e-04
# Epoch 30/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6182 - accuracy: 0.3285
# Epoch 30: val_loss did not improve from 1.84561
# 504/504 [==============================] - 164s 325ms/step - loss: 1.6182 - accuracy: 0.3285 - val_loss: 1.8559 - val_accuracy: 0.2089 - lr: 1.3534e-04
# Epoch 31/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6115 - accuracy: 0.3334
# Epoch 31: val_loss did not improve from 1.84561
# 504/504 [==============================] - 148s 294ms/step - loss: 1.6115 - accuracy: 0.3334 - val_loss: 1.8620 - val_accuracy: 0.2114 - lr: 1.2246e-04
# Epoch 32/100
# 504/504 [==============================] - ETA: 0s - loss: 1.6146 - accuracy: 0.3336
# Epoch 32: val_loss did not improve from 1.84561
# 504/504 [==============================] - 136s 270ms/step - loss: 1.6146 - accuracy: 0.3336 - val_loss: 1.8644 - val_accuracy: 0.2129 - lr: 1.1080e-04

# %% [markdown]
# # Result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

# %%
plt.figure(figsize=(7, 4))
plt.plot((epochs ), history.history['accuracy'], label='Training Accuracy')
plt.plot((epochs ), history.history['val_accuracy'], label='Validation Accuracy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.plot(epochs, history.history['loss'], label='Training Loss')
plt.plot(epochs, history.history['val_loss'], label='Validation Loss')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
score = model.evaluate(validation_generator ,verbose=1)
print('Test Loss:', score[0])
print('Test accuracy:', score[1]*100)
# Out:
# 126/126 [==============================] - 27s 214ms/step - loss: 1.8655 - accuracy: 0.2141
# Test Loss: 1.8655284643173218
# Test accuracy: 21.409079432487488

# %%
import numpy as np
from sklearn.metrics import classification_report


pred = model.predict(validation_generator)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(pred, axis=1)

# Get the true labels from the validation generator
true_labels = validation_generator.classes

# Get class labels
class_labels = list(validation_generator.class_indices.keys())

# Compute the classification report with zero_division parameter set to 'warn'
report = classification_report(true_labels, predicted_labels, target_names=class_labels, zero_division=1)

print("Classification Report:")
print(report)
# Out:
# 126/126 [==============================] - 29s 216ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#      G_Angry       0.15      0.24      0.19       600
#    G_Disgust       0.13      0.01      0.02       600
#       G_Fear       0.14      0.21      0.17       600
#      G_Happy       0.40      0.01      0.01       600
#    G_Neutral       0.13      0.11      0.12       431
#        G_Sad       0.16      0.07      0.09       600
#   G_Surprise       0.15      0.38      0.21       600
#
#     accuracy                           0.15      4031
#    macro avg       0.18      0.15      0.12      4031
# weighted avg       0.18      0.15      0.12      4031

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Compute confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix with adjusted figure size
plt.figure(figsize=(12, 12))  # Adjust the figure size as needed
disp.plot()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.yticks(rotation=45)  # Rotate y-axis labels for better readability
plt.show()

# %%
# target_names = []
# y_pred = model.predict(validation_generator).argmax(axis=1)
# for key in validation_generator.class_indices:
#     target_names.append(key)

# #print(target_names)

# from sklearn.metrics import classification_report

# # Compute the classification report with zero_division parameter set to 'warn'
# report = classification_report(validation_generator.classes, y_pred, target_names=target_names, zero_division=1)

# print('Classification Report:')
# print(report)
