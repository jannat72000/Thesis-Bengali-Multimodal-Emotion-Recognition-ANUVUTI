# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
from IPython.display import Audio
import librosa
import librosa.display

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data_dir = 'E:\\Capstone\\Dataset\\Noisy_Audio'

# %%
# Initialize empty lists for features and labels
features = []
labels = []
for folder in os.listdir(data_dir):
    folder_path = os.path.join(data_dir, folder)
    if os.path.isdir(folder_path):
        emotion_label = folder.split('_')[-1]  # Extract the emotion label from the folder name
        print(emotion_label)

        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if file_path.endswith('.wav'):
                # Load the audio file and extract features
                audio, sr = librosa.load(file_path, duration=3)  # Adjust the duration as needed
                mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40) #13
                mfcc_mean = np.mean(mfcc, axis=1)
                features.append(mfcc_mean)
                labels.append(emotion_label)
# Out:
# Angry
# Disgust
# Fear
# Happy
# Neutral
# Sad
# Surprise

# %%
features = np.array(features)
labels = np.array(labels)

# %%
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# %%
# Define the emotions and the number of samples to select from each emotion
emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad','Surprise']
num_samples_per_emotion = 2
# Initialize empty lists for storing the selected samples
selected_samples = []

# %%
# Iterate through the emotions and select samples
for emotion in emotions:
    emotion_dir = os.path.join(data_dir, f'{emotion}')
    audio_files = os.listdir(emotion_dir)
    selected_files = np.random.choice(audio_files, size=num_samples_per_emotion, replace=False)
    
    for file_name in selected_files:
        file_path = os.path.join(emotion_dir, file_name)
        audio, sr = librosa.load(file_path, duration=3)
        selected_samples.append((audio, sr, emotion))

# %%
for i in range(len(selected_samples)):
    print(selected_samples[i][-1])
# Out:
# Angry
# Angry
# Disgust
# Disgust
# Fear
# Fear
# Happy
# Happy
# Neutral
# Neutral
# Sad
# Sad
# Surprise
# Surprise

# %%
# Plot the selected samples
num_samples = len(selected_samples)
plt.figure(figsize=(8, 4 * num_samples))

for i, (audio, sr, emotion) in enumerate(selected_samples):
    plt.subplot(num_samples, 1, i + 1)
    plt.plot(audio)
    plt.title(f'Waveform - {emotion}')

plt.tight_layout()
plt.show()

# %%
# Calculate the spectrogram
spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr)

# Convert power spectrogram to dB scale
spectrogram_db = librosa.power_to_db(spectrogram, ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(10, 3))
librosa.display.specshow(spectrogram_db, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Surprise Spectrogram')
plt.tight_layout()
plt.show()
Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import librosa

# Define your pitch function
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=pitch_factor)

# Define your sampling rate
sampling_rate = 44100  # For example, adjust this according to your data

# Apply audio transformations (e.g., noise addition, time stretching, pitch shifting)
augmented_features = []
augmented_labels = []

for feature, label in zip(features, labels):
    augmented_features.append(feature)
    augmented_labels.append(label)
    
    # Apply noise addition
    noise = np.random.randn(len(feature))
    augmented_features.append(feature + 0.005 * noise)  # Adjust the noise magnitude as needed
    augmented_labels.append(label)
    
    # Apply time stretching
    stretched_feature = librosa.effects.time_stretch(feature, rate=1.2)  # Adjust the rate as needed
    padded_feature = np.pad(stretched_feature, (0, len(feature) - len(stretched_feature)), mode='constant')
    augmented_features.append(padded_feature)
    augmented_labels.append(label)
    
    # Apply pitch shifting
    pitch_shifted_feature = pitch(feature, sampling_rate)  # Assuming sampling_rate is defined
    max_len = len(feature)  # Assuming max_len is defined
    pitch_shifted_feature = np.pad(pitch_shifted_feature, (0, max_len - len(pitch_shifted_feature)), 'constant')
    augmented_features.append(pitch_shifted_feature)
    augmented_labels.append(label)

# Convert the augmented lists to NumPy arrays
augmented_features = np.array(augmented_features)
augmented_labels = np.array(augmented_labels)

# Print the number of original and augmented samples
print('Original samples:', len(features))
print('Augmented samples:', len(augmented_features))
# Out:
# Original samples: 1032
# Augmented samples: 4128

# %%
# Define a list to store the preprocessed data
preprocessed_data = []
file_list = os.listdir(data_dir)
# Iterate over the files
for filename in file_list:
    file_path = os.path.join(data_dir, filename)
    
    # Skip non-audio files
    if not filename.endswith('.wav'):
        continue

    # Load the audio file and obtain the waveform and sample rate
    waveform, sr = librosa.load(file_path, sr=None, dtype=np.float32)

    # Resample the audio if needed
    if sr != 22050:
        waveform = librosa.resample(waveform, sr, 22050)
        sr = 22050

# %%
# Encode the emotion labels
label_mapping = {'Angry': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise' : 6}
encoded_labels = np.array([label_mapping[label] for label in augmented_labels])

# Convert the emotion labels to categorical format
num_classes = len(label_mapping)
y_categorical = to_categorical(encoded_labels, num_classes)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(augmented_features, y_categorical, test_size=0.2, random_state=42)

# Reshape the input features
X_train = X_train.reshape((*X_train.shape, 1))
X_test = X_test.reshape((*X_test.shape, 1))

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (3302, 40, 1)
# y_train shape: (3302, 7)
# X_test shape: (826, 40, 1)
# y_test shape: (826, 7)

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(40, 1, 1), padding='same'))
model.add(Dropout(0.1))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 1, 64)         640
#
#  dropout (Dropout)           (None, 40, 1, 64)         0
#
#  flatten (Flatten)           (None, 2560)              0
#
#  dense (Dense)               (None, 512)               1311232
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 1315463 (5.02 MB)
# Trainable params: 1315463 (5.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)

print("Test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 104/104 [==============================] - 3s 20ms/step - loss: 2.4745 - accuracy: 0.3383 - val_loss: 1.4576 - val_accuracy: 0.4274
# Epoch 2/100
# 104/104 [==============================] - 2s 16ms/step - loss: 1.3465 - accuracy: 0.4797 - val_loss: 1.3001 - val_accuracy: 0.4867
# Epoch 3/100
# 104/104 [==============================] - 2s 16ms/step - loss: 1.1664 - accuracy: 0.5542 - val_loss: 1.1108 - val_accuracy: 0.5714
# Epoch 4/100
# 104/104 [==============================] - 2s 20ms/step - loss: 0.9872 - accuracy: 0.6208 - val_loss: 0.9430 - val_accuracy: 0.6126
# Epoch 5/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.8489 - accuracy: 0.6829 - val_loss: 0.8536 - val_accuracy: 0.6392
# Epoch 6/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.7159 - accuracy: 0.7368 - val_loss: 0.7076 - val_accuracy: 0.7349
# Epoch 7/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.5929 - accuracy: 0.7847 - val_loss: 0.6163 - val_accuracy: 0.7785
# Epoch 8/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.4953 - accuracy: 0.8231 - val_loss: 0.5114 - val_accuracy: 0.8087
# Epoch 9/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.4198 - accuracy: 0.8471 - val_loss: 0.4725 - val_accuracy: 0.8293
# Epoch 10/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.3405 - accuracy: 0.8816 - val_loss: 0.3874 - val_accuracy: 0.8705
# Epoch 11/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.2789 - accuracy: 0.9034 - val_loss: 0.3979 - val_accuracy: 0.8656
# Epoch 12/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.2846 - accuracy: 0.9007 - val_loss: 0.3680 - val_accuracy: 0.8668
# Epoch 13/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.2214 - accuracy: 0.9276 - val_loss: 0.3608 - val_accuracy: 0.8668
# Epoch 14/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1893 - accuracy: 0.9358 - val_loss: 0.2995 - val_accuracy: 0.8947
# Epoch 15/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1444 - accuracy: 0.9555 - val_loss: 0.2615 - val_accuracy: 0.9068
# Epoch 16/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1392 - accuracy: 0.9558 - val_loss: 0.2960 - val_accuracy: 0.9104
# Epoch 17/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.1258 - accuracy: 0.9588 - val_loss: 0.2696 - val_accuracy: 0.9177
# Epoch 18/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1081 - accuracy: 0.9658 - val_loss: 0.2596 - val_accuracy: 0.9153
# Epoch 19/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1193 - accuracy: 0.9552 - val_loss: 0.2950 - val_accuracy: 0.9031
# Epoch 20/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1163 - accuracy: 0.9621 - val_loss: 0.2519 - val_accuracy: 0.9237
# Epoch 21/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0907 - accuracy: 0.9706 - val_loss: 0.3254 - val_accuracy: 0.8959
# Epoch 22/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.1267 - accuracy: 0.9582 - val_loss: 0.2314 - val_accuracy: 0.9310
# Epoch 23/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1296 - accuracy: 0.9609 - val_loss: 0.2303 - val_accuracy: 0.9262
# Epoch 24/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0865 - accuracy: 0.9740 - val_loss: 0.2624 - val_accuracy: 0.9189
# Epoch 25/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0888 - accuracy: 0.9706 - val_loss: 0.2109 - val_accuracy: 0.9334
# Epoch 26/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0545 - accuracy: 0.9839 - val_loss: 0.3296 - val_accuracy: 0.9165
# Epoch 27/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0944 - accuracy: 0.9670 - val_loss: 0.2737 - val_accuracy: 0.9128
# Epoch 28/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0560 - accuracy: 0.9803 - val_loss: 0.2290 - val_accuracy: 0.9334
# Epoch 29/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0985 - accuracy: 0.9649 - val_loss: 0.2860 - val_accuracy: 0.9189
# Epoch 30/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0722 - accuracy: 0.9764 - val_loss: 0.2336 - val_accuracy: 0.9370
# Epoch 31/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0806 - accuracy: 0.9746 - val_loss: 0.2469 - val_accuracy: 0.9286
# Epoch 32/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0676 - accuracy: 0.9782 - val_loss: 0.2957 - val_accuracy: 0.9310
# Epoch 33/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0760 - accuracy: 0.9724 - val_loss: 0.3515 - val_accuracy: 0.9249
# Epoch 34/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0596 - accuracy: 0.9794 - val_loss: 0.2533 - val_accuracy: 0.9249
# Epoch 35/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0385 - accuracy: 0.9891 - val_loss: 0.2225 - val_accuracy: 0.9407
# Epoch 36/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0530 - accuracy: 0.9833 - val_loss: 0.2467 - val_accuracy: 0.9310
# Epoch 37/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0588 - accuracy: 0.9806 - val_loss: 0.3193 - val_accuracy: 0.9237
# Epoch 38/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0669 - accuracy: 0.9800 - val_loss: 0.2486 - val_accuracy: 0.9395
# Epoch 39/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0520 - accuracy: 0.9849 - val_loss: 0.2501 - val_accuracy: 0.9419
# Epoch 40/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0585 - accuracy: 0.9788 - val_loss: 0.3118 - val_accuracy: 0.9310
# Epoch 41/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0399 - accuracy: 0.9876 - val_loss: 0.2959 - val_accuracy: 0.9274
# Epoch 42/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0539 - accuracy: 0.9827 - val_loss: 0.2718 - val_accuracy: 0.9286
# Epoch 43/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0667 - accuracy: 0.9788 - val_loss: 0.2323 - val_accuracy: 0.9455
# Epoch 44/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0540 - accuracy: 0.9818 - val_loss: 0.2627 - val_accuracy: 0.9370
# Epoch 45/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0425 - accuracy: 0.9858 - val_loss: 0.2588 - val_accuracy: 0.9395
# Epoch 46/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0598 - accuracy: 0.9776 - val_loss: 0.2914 - val_accuracy: 0.9322
# Epoch 47/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0459 - accuracy: 0.9812 - val_loss: 0.2972 - val_accuracy: 0.9310
# Epoch 48/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0516 - accuracy: 0.9803 - val_loss: 0.2755 - val_accuracy: 0.9419
# Epoch 49/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0479 - accuracy: 0.9830 - val_loss: 0.2849 - val_accuracy: 0.9419
# Epoch 50/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.2476 - val_accuracy: 0.9407
# Epoch 51/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0412 - accuracy: 0.9843 - val_loss: 0.2595 - val_accuracy: 0.9455
# Epoch 52/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0507 - accuracy: 0.9803 - val_loss: 0.3109 - val_accuracy: 0.9310
# Epoch 53/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0418 - accuracy: 0.9852 - val_loss: 0.2817 - val_accuracy: 0.9467
# Epoch 54/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0350 - accuracy: 0.9903 - val_loss: 0.3228 - val_accuracy: 0.9298
# Epoch 55/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0388 - accuracy: 0.9921 - val_loss: 0.2769 - val_accuracy: 0.9407
# Epoch 56/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0310 - accuracy: 0.9894 - val_loss: 0.3655 - val_accuracy: 0.9407
# Epoch 57/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0657 - accuracy: 0.9776 - val_loss: 0.3558 - val_accuracy: 0.9322
# Epoch 58/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0590 - accuracy: 0.9809 - val_loss: 0.2983 - val_accuracy: 0.9274
# Epoch 59/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0578 - accuracy: 0.9833 - val_loss: 0.2823 - val_accuracy: 0.9322
# Epoch 60/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0597 - accuracy: 0.9806 - val_loss: 0.2331 - val_accuracy: 0.9395
# Epoch 61/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0570 - accuracy: 0.9843 - val_loss: 0.2352 - val_accuracy: 0.9516
# Epoch 62/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0394 - accuracy: 0.9867 - val_loss: 0.2649 - val_accuracy: 0.9407
# Epoch 63/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0469 - accuracy: 0.9870 - val_loss: 0.2815 - val_accuracy: 0.9322
# Epoch 64/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0439 - accuracy: 0.9882 - val_loss: 0.3499 - val_accuracy: 0.9358
# Epoch 65/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0464 - accuracy: 0.9873 - val_loss: 0.3084 - val_accuracy: 0.9322
# Epoch 66/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0436 - accuracy: 0.9855 - val_loss: 0.3161 - val_accuracy: 0.9383
# Epoch 67/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0425 - accuracy: 0.9879 - val_loss: 0.3417 - val_accuracy: 0.9286
# Epoch 68/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0420 - accuracy: 0.9873 - val_loss: 0.2986 - val_accuracy: 0.9346
# Epoch 69/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.2664 - val_accuracy: 0.9492
# Epoch 70/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0305 - accuracy: 0.9888 - val_loss: 0.2661 - val_accuracy: 0.9467
# Epoch 71/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0278 - accuracy: 0.9915 - val_loss: 0.3387 - val_accuracy: 0.9370
# Epoch 72/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0296 - accuracy: 0.9885 - val_loss: 0.3066 - val_accuracy: 0.9334
# Epoch 73/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0383 - accuracy: 0.9891 - val_loss: 0.3005 - val_accuracy: 0.9443
# Epoch 74/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0420 - accuracy: 0.9846 - val_loss: 0.3041 - val_accuracy: 0.9407
# Epoch 75/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0281 - accuracy: 0.9906 - val_loss: 0.2741 - val_accuracy: 0.9455
# Epoch 76/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0378 - accuracy: 0.9864 - val_loss: 0.2819 - val_accuracy: 0.9479
# Epoch 77/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0121 - accuracy: 0.9970 - val_loss: 0.2613 - val_accuracy: 0.9419
# Epoch 78/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.2687 - val_accuracy: 0.9431
# Epoch 79/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.2923 - val_accuracy: 0.9540
# Epoch 80/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0349 - accuracy: 0.9894 - val_loss: 0.3191 - val_accuracy: 0.9370
# Epoch 81/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0591 - accuracy: 0.9809 - val_loss: 0.3210 - val_accuracy: 0.9419
# Epoch 82/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0631 - accuracy: 0.9806 - val_loss: 0.4147 - val_accuracy: 0.9322
# Epoch 83/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0510 - accuracy: 0.9812 - val_loss: 0.2711 - val_accuracy: 0.9431
# Epoch 84/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0512 - accuracy: 0.9815 - val_loss: 0.2715 - val_accuracy: 0.9443
# Epoch 85/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 0.3558 - val_accuracy: 0.9358
# Epoch 86/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0329 - accuracy: 0.9903 - val_loss: 0.4698 - val_accuracy: 0.9128
# Epoch 87/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0554 - accuracy: 0.9836 - val_loss: 0.3803 - val_accuracy: 0.9298
# Epoch 88/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0347 - accuracy: 0.9894 - val_loss: 0.3028 - val_accuracy: 0.9383
# Epoch 89/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0341 - accuracy: 0.9891 - val_loss: 0.3880 - val_accuracy: 0.9334
# Epoch 90/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.3615 - val_accuracy: 0.9334
# Epoch 91/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0372 - accuracy: 0.9894 - val_loss: 0.2832 - val_accuracy: 0.9443
# Epoch 92/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0230 - accuracy: 0.9930 - val_loss: 0.3505 - val_accuracy: 0.9395
# Epoch 93/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0472 - accuracy: 0.9885 - val_loss: 0.3643 - val_accuracy: 0.9455
# Epoch 94/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0363 - accuracy: 0.9870 - val_loss: 0.3586 - val_accuracy: 0.9334
# Epoch 95/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0440 - accuracy: 0.9870 - val_loss: 0.3814 - val_accuracy: 0.9370
# Epoch 96/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0549 - accuracy: 0.9836 - val_loss: 0.3804 - val_accuracy: 0.9370
# Epoch 97/100
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0524 - accuracy: 0.9827 - val_loss: 0.4155 - val_accuracy: 0.9262
# Epoch 98/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0373 - accuracy: 0.9894 - val_loss: 0.4017 - val_accuracy: 0.9334
# Epoch 99/100
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0266 - accuracy: 0.9906 - val_loss: 0.3927 - val_accuracy: 0.9358
# Epoch 100/100
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0396 - accuracy: 0.9876 - val_loss: 0.3649 - val_accuracy: 0.9419
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3649 - accuracy: 0.9419
# Test loss: 0.36485350131988525
# Test accuracy: 0.9418886303901672

# %%
print("Accuracy of our model on test data : " , model.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3649 - accuracy: 0.9419
# Accuracy of our model on test data :  94.18886303901672 %

# %%
# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Get the predicted labels for the test set
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)  # Convert one-hot encoded predictions to labels

# Convert the true labels from one-hot encoding to labels
y_true_labels = np.argmax(y_test, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)

class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad','surprise']  # Replace with your actual class names
report = classification_report(y_true_labels, y_pred_labels, target_names=class_names, labels=range(len(class_names)))

# Display the confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
print(report)
# Out:
# 26/26 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#        angry       0.95      0.93      0.94       143
#      disgust       0.93      0.97      0.95       121
#         fear       0.92      0.93      0.93       119
#        happy       0.91      0.91      0.91       117
#      neutral       0.97      0.98      0.97        95
#          sad       0.97      0.94      0.96       108
#     surprise       0.95      0.94      0.95       123
#
#     accuracy                           0.94       826
#    macro avg       0.94      0.94      0.94       826
# weighted avg       0.94      0.94      0.94       826

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.97      1.00      0.98        91
#      disgust       0.00      0.00      0.00         0
#         fear       1.00      1.00      1.00        89
#        happy       1.00      0.97      0.98        92
#      neutral       1.00      1.00      1.00        80
#          sad       1.00      1.00      1.00        97
#     surprise       1.00      1.00      1.00        81
#
#    micro avg       0.99      0.99      0.99       530
#    macro avg       0.85      0.85      0.85       530
# weighted avg       0.99      0.99      0.99       530

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 83/83 [==============================] - 2s 18ms/step - loss: 0.0242 - accuracy: 0.9913 - val_loss: 0.0027 - val_accuracy: 0.9985
# Epoch 2/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0187 - accuracy: 0.9936 - val_loss: 0.0067 - val_accuracy: 0.9985
# Epoch 3/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0300 - accuracy: 0.9902 - val_loss: 0.0044 - val_accuracy: 0.9985
# Epoch 4/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0348 - accuracy: 0.9890 - val_loss: 0.0062 - val_accuracy: 0.9985
# Epoch 5/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0435 - accuracy: 0.9867 - val_loss: 0.0133 - val_accuracy: 0.9955
# Epoch 6/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0570 - accuracy: 0.9826 - val_loss: 0.0092 - val_accuracy: 0.9970
# Epoch 7/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0427 - accuracy: 0.9886 - val_loss: 0.0086 - val_accuracy: 0.9955
# Epoch 8/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0226 - accuracy: 0.9951 - val_loss: 0.0026 - val_accuracy: 0.9985
# Epoch 9/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0273 - accuracy: 0.9913 - val_loss: 0.0116 - val_accuracy: 0.9970
# Epoch 10/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.0023 - val_accuracy: 0.9985
# Epoch 11/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0300 - accuracy: 0.9894 - val_loss: 0.0186 - val_accuracy: 0.9924
# Epoch 12/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0265 - accuracy: 0.9905 - val_loss: 0.0058 - val_accuracy: 0.9985
# Epoch 13/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0288 - accuracy: 0.9924 - val_loss: 0.0093 - val_accuracy: 0.9970
# Epoch 14/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.0082 - val_accuracy: 0.9985
# Epoch 15/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0304 - accuracy: 0.9909 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 16/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0220 - accuracy: 0.9920 - val_loss: 0.0062 - val_accuracy: 0.9985
# Epoch 17/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0141 - accuracy: 0.9947 - val_loss: 0.0071 - val_accuracy: 0.9955
# Epoch 18/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0245 - accuracy: 0.9966 - val_loss: 0.0118 - val_accuracy: 0.9939
# Epoch 19/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0173 - accuracy: 0.9928 - val_loss: 0.0074 - val_accuracy: 0.9985
# Epoch 20/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0159 - accuracy: 0.9936 - val_loss: 0.0166 - val_accuracy: 0.9985
# Epoch 21/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0334 - accuracy: 0.9902 - val_loss: 0.0181 - val_accuracy: 0.9924
# Epoch 22/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0343 - accuracy: 0.9902 - val_loss: 0.0239 - val_accuracy: 0.9939
# Epoch 23/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0400 - accuracy: 0.9894 - val_loss: 0.0091 - val_accuracy: 0.9955
# Epoch 24/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0473 - accuracy: 0.9875 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 25/100
# 83/83 [==============================] - 2s 18ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0065 - val_accuracy: 0.9985
# Epoch 26/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0373 - accuracy: 0.9898 - val_loss: 0.0066 - val_accuracy: 0.9970
# Epoch 27/100
# 83/83 [==============================] - 2s 23ms/step - loss: 0.0395 - accuracy: 0.9894 - val_loss: 0.0696 - val_accuracy: 0.9834
# Epoch 28/100
# 83/83 [==============================] - 3s 33ms/step - loss: 0.0724 - accuracy: 0.9814 - val_loss: 0.0613 - val_accuracy: 0.9803
# Epoch 29/100
# 83/83 [==============================] - 2s 24ms/step - loss: 0.0494 - accuracy: 0.9875 - val_loss: 0.0183 - val_accuracy: 0.9985
# Epoch 30/100
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0225 - accuracy: 0.9917 - val_loss: 0.0093 - val_accuracy: 0.9939
# Epoch 31/100
# 83/83 [==============================] - 2s 24ms/step - loss: 0.0332 - accuracy: 0.9913 - val_loss: 0.0378 - val_accuracy: 0.9924
# Epoch 32/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0397 - accuracy: 0.9905 - val_loss: 0.0309 - val_accuracy: 0.9939
# Epoch 33/100
# 83/83 [==============================] - 2s 19ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.0092 - val_accuracy: 0.9970
# Epoch 34/100
# 83/83 [==============================] - 2s 24ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 0.0065 - val_accuracy: 0.9970
# Epoch 35/100
# 83/83 [==============================] - 2s 19ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0085 - val_accuracy: 0.9955
# Epoch 36/100
# 83/83 [==============================] - 2s 19ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.0119 - val_accuracy: 0.9939
# Epoch 37/100
# 83/83 [==============================] - 2s 19ms/step - loss: 0.0360 - accuracy: 0.9909 - val_loss: 0.0449 - val_accuracy: 0.9894
# Epoch 38/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0363 - accuracy: 0.9894 - val_loss: 0.0226 - val_accuracy: 0.9924
# Epoch 39/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0542 - accuracy: 0.9875 - val_loss: 0.0215 - val_accuracy: 0.9909
# Epoch 40/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0278 - accuracy: 0.9924 - val_loss: 0.0096 - val_accuracy: 0.9939
# Epoch 41/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0147 - accuracy: 0.9962 - val_loss: 0.0197 - val_accuracy: 0.9909
# Epoch 42/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0223 - val_accuracy: 0.9955
# Epoch 43/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0208 - accuracy: 0.9917 - val_loss: 0.0260 - val_accuracy: 0.9909
# Epoch 44/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0293 - accuracy: 0.9894 - val_loss: 0.0218 - val_accuracy: 0.9909
# Epoch 45/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0560 - accuracy: 0.9886 - val_loss: 0.0358 - val_accuracy: 0.9879
# Epoch 46/100
# 83/83 [==============================] - 2s 19ms/step - loss: 0.0580 - accuracy: 0.9864 - val_loss: 0.0620 - val_accuracy: 0.9803
# Epoch 47/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0517 - accuracy: 0.9830 - val_loss: 0.0493 - val_accuracy: 0.9849
# Epoch 48/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 0.0401 - val_accuracy: 0.9864
# Epoch 49/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0302 - accuracy: 0.9928 - val_loss: 0.0161 - val_accuracy: 0.9939
# Epoch 50/100
# 83/83 [==============================] - 2s 19ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0144 - val_accuracy: 0.9955
# Epoch 51/100
# 83/83 [==============================] - 2s 20ms/step - loss: 0.0093 - accuracy: 0.9981 - val_loss: 0.0070 - val_accuracy: 0.9955
# Epoch 52/100
# 83/83 [==============================] - 2s 18ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0219 - val_accuracy: 0.9894
# Epoch 53/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0265 - accuracy: 0.9928 - val_loss: 0.0202 - val_accuracy: 0.9924
# Epoch 54/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0422 - accuracy: 0.9852 - val_loss: 0.0539 - val_accuracy: 0.9803
# Epoch 55/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0180 - accuracy: 0.9951 - val_loss: 0.0407 - val_accuracy: 0.9849
# Epoch 56/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.0104 - val_accuracy: 0.9970
# Epoch 57/100
# 83/83 [==============================] - 2s 20ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0322 - val_accuracy: 0.9879
# Epoch 58/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0097 - accuracy: 0.9962 - val_loss: 0.0103 - val_accuracy: 0.9970
# Epoch 59/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 0.0215 - val_accuracy: 0.9939
# Epoch 60/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0223 - accuracy: 0.9947 - val_loss: 0.0251 - val_accuracy: 0.9894
# Epoch 61/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0193 - accuracy: 0.9939 - val_loss: 0.0405 - val_accuracy: 0.9879
# Epoch 62/100
# 83/83 [==============================] - 2s 20ms/step - loss: 0.0448 - accuracy: 0.9902 - val_loss: 0.0384 - val_accuracy: 0.9849
# Epoch 63/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0167 - val_accuracy: 0.9955
# Epoch 64/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.0272 - val_accuracy: 0.9924
# Epoch 65/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0282 - accuracy: 0.9932 - val_loss: 0.0266 - val_accuracy: 0.9924
# Epoch 66/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0156 - accuracy: 0.9962 - val_loss: 0.0322 - val_accuracy: 0.9894
# Epoch 67/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0179 - accuracy: 0.9939 - val_loss: 0.0429 - val_accuracy: 0.9849
# Epoch 68/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0218 - accuracy: 0.9932 - val_loss: 0.0232 - val_accuracy: 0.9864
# Epoch 69/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 0.0193 - val_accuracy: 0.9939
# Epoch 70/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0321 - accuracy: 0.9909 - val_loss: 0.0268 - val_accuracy: 0.9909
# Epoch 71/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0244 - accuracy: 0.9917 - val_loss: 0.0367 - val_accuracy: 0.9818
# Epoch 72/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0197 - accuracy: 0.9936 - val_loss: 0.0269 - val_accuracy: 0.9909
# Epoch 73/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0353 - accuracy: 0.9917 - val_loss: 0.0557 - val_accuracy: 0.9879
# Epoch 74/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0412 - accuracy: 0.9894 - val_loss: 0.0729 - val_accuracy: 0.9803
# Epoch 75/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0301 - accuracy: 0.9917 - val_loss: 0.0321 - val_accuracy: 0.9894
# Epoch 76/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0315 - accuracy: 0.9909 - val_loss: 0.1020 - val_accuracy: 0.9834
# Epoch 77/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0348 - accuracy: 0.9890 - val_loss: 0.0385 - val_accuracy: 0.9818
# Epoch 78/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0327 - accuracy: 0.9902 - val_loss: 0.1047 - val_accuracy: 0.9743
# Epoch 79/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0277 - accuracy: 0.9917 - val_loss: 0.0538 - val_accuracy: 0.9834
# Epoch 80/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0140 - accuracy: 0.9966 - val_loss: 0.0589 - val_accuracy: 0.9864
# Epoch 81/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.0378 - val_accuracy: 0.9894
# Epoch 82/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0295 - accuracy: 0.9917 - val_loss: 0.0782 - val_accuracy: 0.9773
# Epoch 83/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0501 - accuracy: 0.9890 - val_loss: 0.1550 - val_accuracy: 0.9728
# Epoch 84/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0275 - accuracy: 0.9924 - val_loss: 0.1066 - val_accuracy: 0.9803
# Epoch 85/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0287 - accuracy: 0.9924 - val_loss: 0.0588 - val_accuracy: 0.9849
# Epoch 86/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0268 - accuracy: 0.9928 - val_loss: 0.0704 - val_accuracy: 0.9834
# Epoch 87/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0400 - accuracy: 0.9917 - val_loss: 0.0624 - val_accuracy: 0.9803
# Epoch 88/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.0435 - val_accuracy: 0.9818
# Epoch 89/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0101 - accuracy: 0.9955 - val_loss: 0.0378 - val_accuracy: 0.9909
# Epoch 90/100
# 83/83 [==============================] - 1s 15ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0835 - val_accuracy: 0.9834
# Epoch 91/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0324 - accuracy: 0.9913 - val_loss: 0.0732 - val_accuracy: 0.9788
# Epoch 92/100
# 83/83 [==============================] - 2s 18ms/step - loss: 0.0264 - accuracy: 0.9902 - val_loss: 0.0548 - val_accuracy: 0.9834
# Epoch 93/100
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0149 - accuracy: 0.9943 - val_loss: 0.0719 - val_accuracy: 0.9788
# Epoch 94/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0143 - accuracy: 0.9955 - val_loss: 0.0464 - val_accuracy: 0.9849
# Epoch 95/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0165 - accuracy: 0.9958 - val_loss: 0.0411 - val_accuracy: 0.9864
# Epoch 96/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0588 - accuracy: 0.9909 - val_loss: 0.0688 - val_accuracy: 0.9743
# Epoch 97/100
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0274 - accuracy: 0.9936 - val_loss: 0.0828 - val_accuracy: 0.9834
# Epoch 98/100
# 83/83 [==============================] - 1s 16ms/step - loss: 0.0302 - accuracy: 0.9902 - val_loss: 0.0448 - val_accuracy: 0.9909
# Epoch 99/100
# 83/83 [==============================] - 1s 15ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.0318 - val_accuracy: 0.9864
# Epoch 100/100
# 83/83 [==============================] - 1s 15ms/step - loss: 0.0158 - accuracy: 0.9962 - val_loss: 0.0552 - val_accuracy: 0.9849

# %%
print("Accuracy of our model on train data : " , model.evaluate(X_train,y_train)[1]*100 , "%")
# Out:
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0505 - accuracy: 0.9879
# Accuracy of our model on train data :  98.78787994384766 %

# %%
model.save('audio_emotion.h5')
