# %%
import os
import cv2
import numpy as np
import librosa
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import os
import cv2
import numpy as np
import librosa
from tensorflow.keras.preprocessing.sequence import pad_sequences

def extract_frames(video_path, num_frames=30):
    try:
        cap = cv2.VideoCapture(video_path)
        frames = []
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        frame_interval = max(total_frames // num_frames, 1)

        for i in range(num_frames):
            cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)
            ret, frame = cap.read()
            if ret:
                frame = cv2.resize(frame, (224, 224))
                frames.append(frame)
            else:
                break

        cap.release()
        if len(frames) == 0:
            raise ValueError("No frames extracted")
        return np.array(frames)
    except Exception as e:
        print(f"Error extracting frames from {video_path}: {e}")
        return None

def extract_audio_features(audio_path, n_mfcc=40, max_pad_len=862):
    try:
        y, sr = librosa.load(audio_path, sr=None)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        if mfcc.shape[1] < max_pad_len:
            pad_width = max_pad_len - mfcc.shape[1]
            mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')
        else:
            mfcc = mfcc[:, :max_pad_len]
        return mfcc.T
    except Exception as e:
        print(f"Error extracting audio features from {audio_path}: {e}")
        return None

# Paths to dataset
DATASET_PATH = 'E:\\Capstone\\Short Dataset 2'
CLASS_NAMES = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

video_data = []
audio_data = []
labels = []

for class_name in CLASS_NAMES:
    class_path = os.path.join(DATASET_PATH, class_name)
    for video_name in os.listdir(class_path):
        video_path = os.path.join(class_path, video_name)
        if not video_name.endswith('.mp4'):
            continue
        frames = extract_frames(video_path)
        audio_features = extract_audio_features(video_path)

        if frames is not None and audio_features is not None:
            video_data.append(frames)
            audio_data.append(audio_features)
            labels.append(CLASS_NAMES.index(class_name))
        else:
            print(f"Skipping {video_name} due to insufficient data")

# Pad video sequences to a uniform length
video_data_padded = pad_sequences(video_data, padding='post', dtype='float32')

audio_data = pad_sequences(audio_data, padding='post', dtype='float32')  # Pad sequences to the same length
labels = np.array(labels)

print("Video data shape:", video_data_padded.shape) # Use the padded video data
print("Audio data shape:", audio_data.shape)
print("Labels shape:", labels.shape)
# Out:
# C:\Users\ehsan\AppData\Local\Temp\ipykernel_2536\237151489.py:33: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# Video data shape: (350, 30, 224, 224, 3)
# Audio data shape: (350, 862, 40)
# Labels shape: (350,)

# %%
# from tensorflow.keras.applications import MobileNetV2
# from tensorflow.keras.models import Model
# import tensorflow as tf

# # Load pre-trained MobileNetV2 model + higher level layers
# base_model = MobileNetV2(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
# x = base_model.output
# x = tf.keras.layers.GlobalAveragePooling2D()(x)
# video_model = Model(inputs=base_model.input, outputs=x)

# # Extract features from each frame set
# video_features = []
# for frames in video_data:
#     features = video_model.predict(frames)
#     video_features.append(features.mean(axis=0))  # Average features over frames

# video_features = np.array(video_features)
# print("Video features shape:", video_features.shape)
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# Video features shape: (216, 1280)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
import tensorflow as tf

# Load pre-trained VGG16 model + higher level layers
base_model = VGG16(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
video_model = Model(inputs=base_model.input, outputs=x)

# Extract features from each frame set
video_features = []
for frames in video_data:
    features = video_model.predict(frames)
    video_features.append(features.mean(axis=0))  # Average features over frames

video_features = np.array(video_features)
print("Video features shape:", video_features.shape)
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# Video features shape: (350, 512)

# %%
from sklearn.model_selection import train_test_split

X_train_video, X_test_video, X_train_audio, X_test_audio, y_train, y_test = train_test_split(
    video_features, audio_data, labels, test_size=0.3, random_state=42)

# Ensure audio data shape compatibility
X_train_audio = np.expand_dims(X_train_audio, -1)
X_test_audio = np.expand_dims(X_test_audio, -1)

print("Train video shape:", X_train_video.shape)
print("Test video shape:", X_test_video.shape)
print("Train audio shape:", X_train_audio.shape)
print("Test audio shape:", X_test_audio.shape)
print("Train labels shape:", y_train.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Train video shape: (245, 512)
# Test video shape: (105, 512)
# Train audio shape: (245, 862, 40, 1)
# Test audio shape: (105, 862, 40, 1)
# Train labels shape: (245,)
# Test labels shape: (105,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, concatenate, Dropout
from tensorflow.keras.regularizers import l2

video_input = Input(shape=(512,))  # Adjust input shape to match actual video feature dimensions
video_dense = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(video_input)
video_dropout = Dropout(0.5)(video_dense)

# Audio model
audio_input = Input(shape=(862, 40))
audio_lstm = LSTM(128, kernel_regularizer=l2(0.001))(audio_input)
audio_dropout = Dropout(0.5)(audio_lstm)

# Fusion model
merged = concatenate([video_dropout, audio_dropout])
dense_1 = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(merged)
dense_1_dropout = Dropout(0.5)(dense_1)
output = Dense(len(CLASS_NAMES), activation='softmax')(dense_1_dropout)

fusion_model = Model(inputs=[video_input, audio_input], outputs=output)
fusion_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
fusion_model.summary()
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 512)]                0         []
#
#  input_3 (InputLayer)        [(None, 862, 40)]            0         []
#
#  dense (Dense)               (None, 128)                  65664     ['input_2[0][0]']
#
#  lstm (LSTM)                 (None, 128)                  86528     ['input_3[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['lstm[0][0]']
#
#  concatenate (Concatenate)   (None, 256)                  0         ['dropout[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  32896     ['concatenate[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 7)                    903       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 185991 (726.53 KB)
# Trainable params: 185991 (726.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = fusion_model.fit(
    [X_train_video, X_train_audio], y_train,
    validation_data=([X_test_video, X_test_audio], y_test),
    epochs=100, batch_size=16,
    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 16/16 [==============================] - 10s 387ms/step - loss: 5.0611 - accuracy: 0.1469 - val_loss: 2.5929 - val_accuracy: 0.1524
# Epoch 2/100
# 16/16 [==============================] - 5s 316ms/step - loss: 3.1310 - accuracy: 0.1429 - val_loss: 2.2209 - val_accuracy: 0.2095
# Epoch 3/100
# 16/16 [==============================] - 5s 328ms/step - loss: 2.4674 - accuracy: 0.1918 - val_loss: 2.2494 - val_accuracy: 0.1810
# Epoch 4/100
# 16/16 [==============================] - 6s 350ms/step - loss: 2.3105 - accuracy: 0.2245 - val_loss: 2.2442 - val_accuracy: 0.1714
# Epoch 5/100
# 16/16 [==============================] - 6s 351ms/step - loss: 2.2621 - accuracy: 0.2204 - val_loss: 2.1843 - val_accuracy: 0.2095
# Epoch 6/100
# 16/16 [==============================] - 5s 323ms/step - loss: 2.1405 - accuracy: 0.2531 - val_loss: 2.1317 - val_accuracy: 0.2000
# Epoch 7/100
# 16/16 [==============================] - 5s 325ms/step - loss: 2.2027 - accuracy: 0.2163 - val_loss: 2.1025 - val_accuracy: 0.2286
# Epoch 8/100
# 16/16 [==============================] - 5s 328ms/step - loss: 2.1665 - accuracy: 0.2367 - val_loss: 2.0906 - val_accuracy: 0.2190
# Epoch 9/100
# 16/16 [==============================] - 5s 326ms/step - loss: 2.0886 - accuracy: 0.2653 - val_loss: 2.0471 - val_accuracy: 0.2571
# Epoch 10/100
# 16/16 [==============================] - 5s 326ms/step - loss: 2.0336 - accuracy: 0.2286 - val_loss: 2.0242 - val_accuracy: 0.2476
# Epoch 11/100
# 16/16 [==============================] - 5s 331ms/step - loss: 1.9590 - accuracy: 0.3347 - val_loss: 1.9720 - val_accuracy: 0.2381
# Epoch 12/100
# 16/16 [==============================] - 6s 350ms/step - loss: 2.0178 - accuracy: 0.3143 - val_loss: 1.9529 - val_accuracy: 0.2667
# Epoch 13/100
# 16/16 [==============================] - 6s 362ms/step - loss: 1.9763 - accuracy: 0.3020 - val_loss: 1.9549 - val_accuracy: 0.2571
# Epoch 14/100
# 16/16 [==============================] - 6s 353ms/step - loss: 1.9662 - accuracy: 0.3020 - val_loss: 1.9143 - val_accuracy: 0.2476
# Epoch 15/100
# 16/16 [==============================] - 5s 341ms/step - loss: 1.8916 - accuracy: 0.3306 - val_loss: 1.9660 - val_accuracy: 0.2286
# Epoch 16/100
# 16/16 [==============================] - 6s 352ms/step - loss: 1.8470 - accuracy: 0.3633 - val_loss: 1.9112 - val_accuracy: 0.2952
# Epoch 17/100
# 16/16 [==============================] - 5s 344ms/step - loss: 1.8998 - accuracy: 0.3592 - val_loss: 1.9134 - val_accuracy: 0.3143
# Epoch 18/100
# 16/16 [==============================] - 5s 344ms/step - loss: 1.8406 - accuracy: 0.3918 - val_loss: 1.9005 - val_accuracy: 0.3238
# Epoch 19/100
# 16/16 [==============================] - 6s 348ms/step - loss: 1.8234 - accuracy: 0.3469 - val_loss: 1.9015 - val_accuracy: 0.3333
# Epoch 20/100
# 16/16 [==============================] - 6s 349ms/step - loss: 1.8131 - accuracy: 0.3592 - val_loss: 1.9603 - val_accuracy: 0.3143
# Epoch 21/100
# 16/16 [==============================] - 6s 371ms/step - loss: 1.8236 - accuracy: 0.3673 - val_loss: 1.8921 - val_accuracy: 0.3143
# Epoch 22/100
# 16/16 [==============================] - 5s 340ms/step - loss: 1.7413 - accuracy: 0.4000 - val_loss: 1.8176 - val_accuracy: 0.3810
# Epoch 23/100
# 16/16 [==============================] - 5s 335ms/step - loss: 1.7662 - accuracy: 0.4082 - val_loss: 1.7794 - val_accuracy: 0.3714
# Epoch 24/100
# 16/16 [==============================] - 6s 351ms/step - loss: 1.7473 - accuracy: 0.4041 - val_loss: 1.8032 - val_accuracy: 0.2857
# Epoch 25/100
# 16/16 [==============================] - 6s 360ms/step - loss: 1.7120 - accuracy: 0.3878 - val_loss: 1.8087 - val_accuracy: 0.3143
# Epoch 26/100
# 16/16 [==============================] - 6s 357ms/step - loss: 1.6430 - accuracy: 0.4408 - val_loss: 1.7592 - val_accuracy: 0.3524
# Epoch 27/100
# 16/16 [==============================] - 6s 375ms/step - loss: 1.6776 - accuracy: 0.4286 - val_loss: 1.7502 - val_accuracy: 0.3619
# Epoch 28/100
# 16/16 [==============================] - 6s 381ms/step - loss: 1.6135 - accuracy: 0.4653 - val_loss: 1.7469 - val_accuracy: 0.3429
# Epoch 29/100
# 16/16 [==============================] - 6s 391ms/step - loss: 1.5398 - accuracy: 0.4776 - val_loss: 1.7601 - val_accuracy: 0.3429
# Epoch 30/100
# 16/16 [==============================] - 6s 355ms/step - loss: 1.6296 - accuracy: 0.4490 - val_loss: 1.7433 - val_accuracy: 0.3333
# Epoch 31/100
# 16/16 [==============================] - 6s 363ms/step - loss: 1.6340 - accuracy: 0.4449 - val_loss: 1.7437 - val_accuracy: 0.3429
# Epoch 32/100
# 16/16 [==============================] - 5s 344ms/step - loss: 1.6499 - accuracy: 0.4327 - val_loss: 1.6985 - val_accuracy: 0.3429
# Epoch 33/100
# 16/16 [==============================] - 6s 356ms/step - loss: 1.5274 - accuracy: 0.4857 - val_loss: 1.6740 - val_accuracy: 0.3429
# Epoch 34/100
# 16/16 [==============================] - 5s 345ms/step - loss: 1.5003 - accuracy: 0.4939 - val_loss: 1.6840 - val_accuracy: 0.3714
# Epoch 35/100
# 16/16 [==============================] - 6s 350ms/step - loss: 1.5948 - accuracy: 0.4571 - val_loss: 1.6822 - val_accuracy: 0.3429
# Epoch 36/100
# 16/16 [==============================] - 5s 343ms/step - loss: 1.4849 - accuracy: 0.5224 - val_loss: 1.6580 - val_accuracy: 0.3524
# Epoch 37/100
# 16/16 [==============================] - 6s 348ms/step - loss: 1.5384 - accuracy: 0.4531 - val_loss: 1.6734 - val_accuracy: 0.3524
# Epoch 38/100
# 16/16 [==============================] - 6s 364ms/step - loss: 1.5010 - accuracy: 0.4980 - val_loss: 1.6656 - val_accuracy: 0.3810
# Epoch 39/100
# 16/16 [==============================] - 5s 340ms/step - loss: 1.4706 - accuracy: 0.5224 - val_loss: 1.6335 - val_accuracy: 0.3905
# Epoch 40/100
# 16/16 [==============================] - 6s 357ms/step - loss: 1.5018 - accuracy: 0.4735 - val_loss: 1.6511 - val_accuracy: 0.4190
# Epoch 41/100
# 16/16 [==============================] - 5s 345ms/step - loss: 1.4412 - accuracy: 0.4898 - val_loss: 1.6301 - val_accuracy: 0.3810
# Epoch 42/100
# 16/16 [==============================] - 5s 342ms/step - loss: 1.4783 - accuracy: 0.4816 - val_loss: 1.5989 - val_accuracy: 0.3905
# Epoch 43/100
# 16/16 [==============================] - 6s 348ms/step - loss: 1.3950 - accuracy: 0.5020 - val_loss: 1.5577 - val_accuracy: 0.4190
# Epoch 44/100
# 16/16 [==============================] - 6s 371ms/step - loss: 1.3735 - accuracy: 0.5469 - val_loss: 1.6290 - val_accuracy: 0.3619
# Epoch 45/100
# 16/16 [==============================] - 6s 346ms/step - loss: 1.3817 - accuracy: 0.5224 - val_loss: 1.5897 - val_accuracy: 0.4381
# Epoch 46/100
# 16/16 [==============================] - 5s 345ms/step - loss: 1.3525 - accuracy: 0.5265 - val_loss: 1.5723 - val_accuracy: 0.4000
# Epoch 47/100
# 16/16 [==============================] - 6s 354ms/step - loss: 1.3698 - accuracy: 0.5184 - val_loss: 1.6117 - val_accuracy: 0.3905
# Epoch 48/100
# 16/16 [==============================] - 5s 337ms/step - loss: 1.3625 - accuracy: 0.5102 - val_loss: 1.5784 - val_accuracy: 0.3429
# Epoch 49/100
# 16/16 [==============================] - 6s 359ms/step - loss: 1.3349 - accuracy: 0.5673 - val_loss: 1.5603 - val_accuracy: 0.3810
# Epoch 50/100
# 16/16 [==============================] - 6s 358ms/step - loss: 1.3910 - accuracy: 0.5102 - val_loss: 1.5531 - val_accuracy: 0.4667
# Epoch 51/100
# 16/16 [==============================] - 6s 367ms/step - loss: 1.2632 - accuracy: 0.5551 - val_loss: 1.5741 - val_accuracy: 0.4095
# Epoch 52/100
# 16/16 [==============================] - 5s 345ms/step - loss: 1.3329 - accuracy: 0.5469 - val_loss: 1.5302 - val_accuracy: 0.4095
# Epoch 53/100
# 16/16 [==============================] - 5s 344ms/step - loss: 1.3127 - accuracy: 0.5184 - val_loss: 1.5181 - val_accuracy: 0.4476
# Epoch 54/100
# 16/16 [==============================] - 5s 345ms/step - loss: 1.2710 - accuracy: 0.6041 - val_loss: 1.5668 - val_accuracy: 0.4095
# Epoch 55/100
# 16/16 [==============================] - 6s 353ms/step - loss: 1.2909 - accuracy: 0.5592 - val_loss: 1.5328 - val_accuracy: 0.4381
# Epoch 56/100
# 16/16 [==============================] - 6s 352ms/step - loss: 1.3191 - accuracy: 0.5510 - val_loss: 1.4975 - val_accuracy: 0.4952
# Epoch 57/100
# 16/16 [==============================] - 6s 360ms/step - loss: 1.2789 - accuracy: 0.5633 - val_loss: 1.5271 - val_accuracy: 0.4190
# Epoch 58/100
# 16/16 [==============================] - 5s 338ms/step - loss: 1.1768 - accuracy: 0.6327 - val_loss: 1.4839 - val_accuracy: 0.4857
# Epoch 59/100
# 16/16 [==============================] - 6s 348ms/step - loss: 1.1468 - accuracy: 0.6245 - val_loss: 1.5706 - val_accuracy: 0.3714
# Epoch 60/100
# 16/16 [==============================] - 6s 353ms/step - loss: 1.1704 - accuracy: 0.5918 - val_loss: 1.5199 - val_accuracy: 0.4190
# Epoch 61/100
# 16/16 [==============================] - 5s 342ms/step - loss: 1.2910 - accuracy: 0.5388 - val_loss: 1.5079 - val_accuracy: 0.4667
# Epoch 62/100
# 16/16 [==============================] - 5s 346ms/step - loss: 1.1842 - accuracy: 0.5959 - val_loss: 1.5211 - val_accuracy: 0.4381
# Epoch 63/100
# 16/16 [==============================] - 6s 355ms/step - loss: 1.1515 - accuracy: 0.6163 - val_loss: 1.4419 - val_accuracy: 0.4667
# Epoch 64/100
# 16/16 [==============================] - 6s 374ms/step - loss: 1.1248 - accuracy: 0.6449 - val_loss: 1.4278 - val_accuracy: 0.4667
# Epoch 65/100
# 16/16 [==============================] - 6s 346ms/step - loss: 1.2336 - accuracy: 0.5429 - val_loss: 1.4757 - val_accuracy: 0.4857
# Epoch 66/100
# 16/16 [==============================] - 6s 361ms/step - loss: 1.1082 - accuracy: 0.6122 - val_loss: 1.5042 - val_accuracy: 0.4762
# Epoch 67/100
# 16/16 [==============================] - 6s 367ms/step - loss: 1.1470 - accuracy: 0.6408 - val_loss: 1.5040 - val_accuracy: 0.4667
# Epoch 68/100
# 16/16 [==============================] - 6s 362ms/step - loss: 1.1531 - accuracy: 0.6041 - val_loss: 1.5476 - val_accuracy: 0.4476
# Epoch 69/100
# 16/16 [==============================] - 6s 381ms/step - loss: 1.0793 - accuracy: 0.6612 - val_loss: 1.5390 - val_accuracy: 0.4190
# Epoch 70/100
# 16/16 [==============================] - 6s 357ms/step - loss: 1.1413 - accuracy: 0.6082 - val_loss: 1.4990 - val_accuracy: 0.4476
# Epoch 71/100
# 16/16 [==============================] - 6s 407ms/step - loss: 1.0496 - accuracy: 0.6816 - val_loss: 1.4337 - val_accuracy: 0.4476
# Epoch 72/100
# 16/16 [==============================] - 6s 371ms/step - loss: 1.0183 - accuracy: 0.6449 - val_loss: 1.4531 - val_accuracy: 0.4667
# Epoch 73/100
# 16/16 [==============================] - 5s 346ms/step - loss: 1.0491 - accuracy: 0.6449 - val_loss: 1.4191 - val_accuracy: 0.4571
# Epoch 74/100
# 16/16 [==============================] - 6s 355ms/step - loss: 1.0994 - accuracy: 0.6204 - val_loss: 1.4109 - val_accuracy: 0.4762
# Epoch 75/100
# 16/16 [==============================] - 6s 360ms/step - loss: 1.0324 - accuracy: 0.6571 - val_loss: 1.4296 - val_accuracy: 0.4667
# Epoch 76/100
# 16/16 [==============================] - 6s 351ms/step - loss: 0.9748 - accuracy: 0.7020 - val_loss: 1.4218 - val_accuracy: 0.4762
# Epoch 77/100
# 16/16 [==============================] - 6s 363ms/step - loss: 1.0230 - accuracy: 0.6612 - val_loss: 1.4563 - val_accuracy: 0.5143
# Epoch 78/100
# 16/16 [==============================] - 5s 346ms/step - loss: 1.0546 - accuracy: 0.6531 - val_loss: 1.4455 - val_accuracy: 0.5048
# Epoch 79/100
# 16/16 [==============================] - 6s 394ms/step - loss: 1.0337 - accuracy: 0.6612 - val_loss: 1.5379 - val_accuracy: 0.4571
# Epoch 80/100
# 16/16 [==============================] - 6s 371ms/step - loss: 1.0845 - accuracy: 0.6204 - val_loss: 1.4351 - val_accuracy: 0.5238
# Epoch 81/100
# 16/16 [==============================] - 6s 352ms/step - loss: 1.0636 - accuracy: 0.6327 - val_loss: 1.4564 - val_accuracy: 0.4857
# Epoch 82/100
# 16/16 [==============================] - 5s 340ms/step - loss: 1.0583 - accuracy: 0.6531 - val_loss: 1.4244 - val_accuracy: 0.5143
# Epoch 83/100
# 16/16 [==============================] - 6s 348ms/step - loss: 1.0880 - accuracy: 0.5878 - val_loss: 1.4090 - val_accuracy: 0.5238
# Epoch 84/100
# 16/16 [==============================] - 6s 361ms/step - loss: 1.0263 - accuracy: 0.6531 - val_loss: 1.4350 - val_accuracy: 0.4952
# Epoch 85/100
# 16/16 [==============================] - 5s 343ms/step - loss: 1.1255 - accuracy: 0.6163 - val_loss: 1.4008 - val_accuracy: 0.4857
# Epoch 86/100
# 16/16 [==============================] - 6s 347ms/step - loss: 1.0498 - accuracy: 0.6245 - val_loss: 1.3644 - val_accuracy: 0.4857
# Epoch 87/100
# 16/16 [==============================] - 6s 349ms/step - loss: 1.0183 - accuracy: 0.6857 - val_loss: 1.4350 - val_accuracy: 0.4952
# Epoch 88/100
# 16/16 [==============================] - 6s 361ms/step - loss: 1.0041 - accuracy: 0.6245 - val_loss: 1.4304 - val_accuracy: 0.5143
# Epoch 89/100
# 16/16 [==============================] - 5s 341ms/step - loss: 1.1408 - accuracy: 0.6041 - val_loss: 1.4015 - val_accuracy: 0.4952
# Epoch 90/100
# 16/16 [==============================] - 6s 351ms/step - loss: 1.0306 - accuracy: 0.6571 - val_loss: 1.3874 - val_accuracy: 0.5048
# Epoch 91/100
# 16/16 [==============================] - 6s 351ms/step - loss: 0.9956 - accuracy: 0.6735 - val_loss: 1.3818 - val_accuracy: 0.5143
# Epoch 92/100
# 16/16 [==============================] - 6s 362ms/step - loss: 1.0289 - accuracy: 0.6367 - val_loss: 1.4466 - val_accuracy: 0.4667
# Epoch 93/100
# 16/16 [==============================] - 6s 349ms/step - loss: 1.0620 - accuracy: 0.6571 - val_loss: 1.3931 - val_accuracy: 0.5048
# Epoch 94/100
# 16/16 [==============================] - 6s 355ms/step - loss: 1.0146 - accuracy: 0.6571 - val_loss: 1.4320 - val_accuracy: 0.4571
# Epoch 95/100
# 16/16 [==============================] - 6s 372ms/step - loss: 1.0091 - accuracy: 0.6612 - val_loss: 1.5290 - val_accuracy: 0.5048
# Epoch 96/100
# 16/16 [==============================] - 6s 364ms/step - loss: 1.0344 - accuracy: 0.6286 - val_loss: 1.4507 - val_accuracy: 0.4857

# %%
# Print the training and validation accuracy/loss
train_accuracy = history.history['accuracy'][-1]
val_accuracy = history.history['val_accuracy'][-1]
train_loss = history.history['loss'][-1]
val_loss = history.history['val_loss'][-1]

print(f"Training Accuracy: {train_accuracy}")
print(f"Validation Accuracy: {val_accuracy}")
print(f"Training Loss: {train_loss}")
print(f"Validation Loss: {val_loss}")
# Out:
# Training Accuracy: 0.6285714507102966
# Validation Accuracy: 0.48571428656578064
# Training Loss: 1.0343985557556152
# Validation Loss: 1.450724720954895

# %%
# Generate classification report
from sklearn.metrics import classification_report
y_pred = np.argmax(fusion_model.predict([X_test_video, X_test_audio]), axis=1)
print(classification_report(y_test, y_pred, target_names=CLASS_NAMES))
# Out:
# 4/4 [==============================] - 1s 137ms/step
#               precision    recall  f1-score   support
#
#        Angry       0.40      0.38      0.39        16
#      Disgust       0.24      0.24      0.24        17
#         Fear       0.54      0.54      0.54        13
#        Happy       0.64      0.60      0.62        15
#      Neutral       1.00      0.93      0.96        14
#          Sad       0.40      0.33      0.36        12
#     Surprise       0.35      0.44      0.39        18
#
#     accuracy                           0.49       105
#    macro avg       0.51      0.49      0.50       105
# weighted avg       0.50      0.49      0.49       105

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the History object returned by model.fit()

# Plot training & validation accuracy values
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the History object returned by model.fit()

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fusion_model.save('E:\\Capstone\\400 C code\\models\\h5 models\\emotion_vgg16_run2.h5')
# Out:
# c:\Python10\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import confusion_matrix

# Generate confusion matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print(confusion_matrix)
# Out:
# [[ 6  4  1  2  0  2  1]
#  [ 3  4  2  0  0  1  7]
#  [ 0  2  7  0  0  0  4]
#  [ 1  1  0  9  0  2  2]
#  [ 0  1  0  0 13  0  0]
#  [ 4  0  1  2  0  4  1]
#  [ 1  5  2  1  0  1  8]]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix # Re-import the function

# Generate confusion matrix using the imported function
cm = confusion_matrix(y_test, y_pred)

# Set up the visualization
sns.set(font_scale=1.4)  # Increase font size
plt.figure(figsize=(8, 6))  # Set figure size

# Create the heatmap using cm
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)

# Add labels and title
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("Actual", fontsize=12)
plt.title("Confusion Matrix", fontsize=14)
plt.tight_layout()  # Improve spacing

# Show the plot
plt.show()
