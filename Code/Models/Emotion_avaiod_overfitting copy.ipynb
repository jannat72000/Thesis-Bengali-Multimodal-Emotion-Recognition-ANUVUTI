# %%
import os
import cv2
import numpy as np
import librosa
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import os
import cv2
import numpy as np
import librosa
from tensorflow.keras.preprocessing.sequence import pad_sequences

def extract_frames(video_path, num_frames=30):
    try:
        cap = cv2.VideoCapture(video_path)
        frames = []
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        frame_interval = max(total_frames // num_frames, 1)

        for i in range(num_frames):
            cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)
            ret, frame = cap.read()
            if ret:
                frame = cv2.resize(frame, (224, 224))
                frames.append(frame)
            else:
                break

        cap.release()
        if len(frames) == 0:
            raise ValueError("No frames extracted")
        return np.array(frames)
    except Exception as e:
        print(f"Error extracting frames from {video_path}: {e}")
        return None

def extract_audio_features(audio_path, n_mfcc=40, max_pad_len=862):
    try:
        y, sr = librosa.load(audio_path, sr=None)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        if mfcc.shape[1] < max_pad_len:
            pad_width = max_pad_len - mfcc.shape[1]
            mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')
        else:
            mfcc = mfcc[:, :max_pad_len]
        return mfcc.T
    except Exception as e:
        print(f"Error extracting audio features from {audio_path}: {e}")
        return None

# Paths to dataset
DATASET_PATH = 'E:\\Capstone\\Short Dataset 3'
CLASS_NAMES = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

video_data = []
audio_data = []
labels = []

for class_name in CLASS_NAMES:
    class_path = os.path.join(DATASET_PATH, class_name)
    for video_name in os.listdir(class_path):
        video_path = os.path.join(class_path, video_name)
        if not video_name.endswith('.mp4'):
            continue
        frames = extract_frames(video_path)
        audio_features = extract_audio_features(video_path)

        if frames is not None and audio_features is not None:
            video_data.append(frames)
            audio_data.append(audio_features)
            labels.append(CLASS_NAMES.index(class_name))
        else:
            print(f"Skipping {video_name} due to insufficient data")

# Pad video sequences to a uniform length
video_data_padded = pad_sequences(video_data, padding='post', dtype='float32')

audio_data = pad_sequences(audio_data, padding='post', dtype='float32')  # Pad sequences to the same length
labels = np.array(labels)

print("Video data shape:", video_data_padded.shape) # Use the padded video data
print("Audio data shape:", audio_data.shape)
print("Labels shape:", labels.shape)
# Out:
# C:\Users\ehsan\AppData\Local\Temp\ipykernel_7336\3595253245.py:33: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# c:\Python10\lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# C:\Users\ehsan\AppData\Local\Temp\ipykernel_7336\3595253245.py:33: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# c:\Python10\lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Video data shape: (216, 30, 224, 224, 3)
# Audio data shape: (216, 862, 40)
# Labels shape: (216,)

# %%
# from tensorflow.keras.applications import MobileNetV2
# from tensorflow.keras.models import Model
# import tensorflow as tf

# # Load pre-trained MobileNetV2 model + higher level layers
# base_model = MobileNetV2(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
# x = base_model.output
# x = tf.keras.layers.GlobalAveragePooling2D()(x)
# video_model = Model(inputs=base_model.input, outputs=x)

# # Extract features from each frame set
# video_features = []
# for frames in video_data:
#     features = video_model.predict(frames)
#     video_features.append(features.mean(axis=0))  # Average features over frames

# video_features = np.array(video_features)
# print("Video features shape:", video_features.shape)
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# Video features shape: (216, 1280)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
import tensorflow as tf

# Load pre-trained VGG16 model + higher level layers
base_model = VGG16(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
video_model = Model(inputs=base_model.input, outputs=x)

# Extract features from each frame set
video_features = []
for frames in video_data:
    features = video_model.predict(frames)
    video_features.append(features.mean(axis=0))  # Average features over frames

video_features = np.array(video_features)
print("Video features shape:", video_features.shape)
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# Video features shape: (216, 512)

# %%
from sklearn.model_selection import train_test_split

X_train_video, X_test_video, X_train_audio, X_test_audio, y_train, y_test = train_test_split(
    video_features, audio_data, labels, test_size=0.3, random_state=42)

# Ensure audio data shape compatibility
X_train_audio = np.expand_dims(X_train_audio, -1)
X_test_audio = np.expand_dims(X_test_audio, -1)

print("Train video shape:", X_train_video.shape)
print("Test video shape:", X_test_video.shape)
print("Train audio shape:", X_train_audio.shape)
print("Test audio shape:", X_test_audio.shape)
print("Train labels shape:", y_train.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Train video shape: (151, 512)
# Test video shape: (65, 512)
# Train audio shape: (151, 862, 40, 1)
# Test audio shape: (65, 862, 40, 1)
# Train labels shape: (151,)
# Test labels shape: (65,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, concatenate, Dropout
from tensorflow.keras.regularizers import l2

video_input = Input(shape=(512,))  # Adjust input shape to match actual video feature dimensions
video_dense = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(video_input)
video_dropout = Dropout(0.5)(video_dense)

# Audio model
audio_input = Input(shape=(862, 40))
audio_lstm = LSTM(128, kernel_regularizer=l2(0.001))(audio_input)
audio_dropout = Dropout(0.5)(audio_lstm)

# Fusion model
merged = concatenate([video_dropout, audio_dropout])
dense_1 = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(merged)
dense_1_dropout = Dropout(0.5)(dense_1)
output = Dense(len(CLASS_NAMES), activation='softmax')(dense_1_dropout)

fusion_model = Model(inputs=[video_input, audio_input], outputs=output)
fusion_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
fusion_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 512)]                0         []
#
#  input_5 (InputLayer)        [(None, 862, 40)]            0         []
#
#  dense_3 (Dense)             (None, 128)                  65664     ['input_4[0][0]']
#
#  lstm_1 (LSTM)               (None, 128)                  86528     ['input_5[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['dense_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['lstm_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 256)                  0         ['dropout_3[0][0]',
#  )                                                                   'dropout_4[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  32896     ['concatenate_1[0][0]']
#
#  dropout_5 (Dropout)         (None, 128)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 7)                    903       ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 185991 (726.53 KB)
# Trainable params: 185991 (726.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = fusion_model.fit(
    [X_train_video, X_train_audio], y_train,
    validation_data=([X_test_video, X_test_audio], y_test),
    epochs=100, batch_size=8,
    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 19/19 [==============================] - 8s 266ms/step - loss: 4.8294 - accuracy: 0.1656 - val_loss: 2.3134 - val_accuracy: 0.2000
# Epoch 2/100
# 19/19 [==============================] - 5s 237ms/step - loss: 3.1188 - accuracy: 0.1589 - val_loss: 2.2148 - val_accuracy: 0.2615
# Epoch 3/100
# 19/19 [==============================] - 4s 233ms/step - loss: 2.5183 - accuracy: 0.1921 - val_loss: 2.1828 - val_accuracy: 0.2154
# Epoch 4/100
# 19/19 [==============================] - 4s 234ms/step - loss: 2.2198 - accuracy: 0.2781 - val_loss: 2.1284 - val_accuracy: 0.3077
# Epoch 5/100
# 19/19 [==============================] - 4s 238ms/step - loss: 2.1535 - accuracy: 0.2781 - val_loss: 2.0882 - val_accuracy: 0.2308
# Epoch 6/100
# 19/19 [==============================] - 5s 241ms/step - loss: 2.1068 - accuracy: 0.2781 - val_loss: 2.0434 - val_accuracy: 0.2615
# Epoch 7/100
# 19/19 [==============================] - 5s 239ms/step - loss: 2.0725 - accuracy: 0.2781 - val_loss: 2.0036 - val_accuracy: 0.2769
# Epoch 8/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.9958 - accuracy: 0.2914 - val_loss: 1.9814 - val_accuracy: 0.2615
# Epoch 9/100
# 19/19 [==============================] - 4s 233ms/step - loss: 2.0085 - accuracy: 0.2914 - val_loss: 1.9117 - val_accuracy: 0.3077
# Epoch 10/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.9539 - accuracy: 0.2517 - val_loss: 1.9086 - val_accuracy: 0.3231
# Epoch 11/100
# 19/19 [==============================] - 4s 238ms/step - loss: 1.8806 - accuracy: 0.3510 - val_loss: 1.8628 - val_accuracy: 0.2769
# Epoch 12/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.8335 - accuracy: 0.3709 - val_loss: 1.8232 - val_accuracy: 0.3846
# Epoch 13/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.9790 - accuracy: 0.2781 - val_loss: 1.9087 - val_accuracy: 0.3077
# Epoch 14/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.8549 - accuracy: 0.2980 - val_loss: 1.8416 - val_accuracy: 0.3538
# Epoch 15/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.8688 - accuracy: 0.3444 - val_loss: 1.8398 - val_accuracy: 0.3538
# Epoch 16/100
# 19/19 [==============================] - 5s 249ms/step - loss: 1.8961 - accuracy: 0.3377 - val_loss: 1.8411 - val_accuracy: 0.3385
# Epoch 17/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.7357 - accuracy: 0.4371 - val_loss: 1.7799 - val_accuracy: 0.3231
# Epoch 18/100
# 19/19 [==============================] - 5s 249ms/step - loss: 1.7085 - accuracy: 0.4040 - val_loss: 1.7021 - val_accuracy: 0.3846
# Epoch 19/100
# 19/19 [==============================] - 5s 238ms/step - loss: 1.8084 - accuracy: 0.3775 - val_loss: 1.7816 - val_accuracy: 0.3385
# Epoch 20/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.7143 - accuracy: 0.3841 - val_loss: 1.7675 - val_accuracy: 0.3538
# Epoch 21/100
# 19/19 [==============================] - 4s 239ms/step - loss: 1.7446 - accuracy: 0.3709 - val_loss: 1.7108 - val_accuracy: 0.3846
# Epoch 22/100
# 19/19 [==============================] - 4s 233ms/step - loss: 1.7179 - accuracy: 0.3775 - val_loss: 1.6755 - val_accuracy: 0.4923
# Epoch 23/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.6971 - accuracy: 0.4172 - val_loss: 1.7313 - val_accuracy: 0.3692
# Epoch 24/100
# 19/19 [==============================] - 4s 237ms/step - loss: 1.6445 - accuracy: 0.4570 - val_loss: 1.6653 - val_accuracy: 0.5077
# Epoch 25/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.5861 - accuracy: 0.4503 - val_loss: 1.6545 - val_accuracy: 0.4000
# Epoch 26/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.6112 - accuracy: 0.4238 - val_loss: 1.6538 - val_accuracy: 0.4462
# Epoch 27/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.5758 - accuracy: 0.3709 - val_loss: 1.6597 - val_accuracy: 0.4000
# Epoch 28/100
# 19/19 [==============================] - 4s 238ms/step - loss: 1.5975 - accuracy: 0.4768 - val_loss: 1.6086 - val_accuracy: 0.4462
# Epoch 29/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.5292 - accuracy: 0.4702 - val_loss: 1.6506 - val_accuracy: 0.3846
# Epoch 30/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.4938 - accuracy: 0.4768 - val_loss: 1.5905 - val_accuracy: 0.3692
# Epoch 31/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.4782 - accuracy: 0.4834 - val_loss: 1.4964 - val_accuracy: 0.4154
# Epoch 32/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.4259 - accuracy: 0.4834 - val_loss: 1.5208 - val_accuracy: 0.4923
# Epoch 33/100
# 19/19 [==============================] - 4s 237ms/step - loss: 1.5973 - accuracy: 0.4437 - val_loss: 1.4998 - val_accuracy: 0.4462
# Epoch 34/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.5185 - accuracy: 0.4437 - val_loss: 1.5626 - val_accuracy: 0.3846
# Epoch 35/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.3535 - accuracy: 0.5232 - val_loss: 1.5803 - val_accuracy: 0.4769
# Epoch 36/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.4332 - accuracy: 0.4967 - val_loss: 1.5224 - val_accuracy: 0.4462
# Epoch 37/100
# 19/19 [==============================] - 5s 241ms/step - loss: 1.4839 - accuracy: 0.4437 - val_loss: 1.5608 - val_accuracy: 0.4462
# Epoch 38/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.4096 - accuracy: 0.5232 - val_loss: 1.5435 - val_accuracy: 0.4154
# Epoch 39/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.3437 - accuracy: 0.5099 - val_loss: 1.4723 - val_accuracy: 0.4923
# Epoch 40/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.3536 - accuracy: 0.4834 - val_loss: 1.5292 - val_accuracy: 0.3846
# Epoch 41/100
# 19/19 [==============================] - 4s 238ms/step - loss: 1.2512 - accuracy: 0.5828 - val_loss: 1.4254 - val_accuracy: 0.4615
# Epoch 42/100
# 19/19 [==============================] - 4s 237ms/step - loss: 1.4788 - accuracy: 0.4768 - val_loss: 1.4591 - val_accuracy: 0.4769
# Epoch 43/100
# 19/19 [==============================] - 4s 233ms/step - loss: 1.3036 - accuracy: 0.5563 - val_loss: 1.5374 - val_accuracy: 0.4615
# Epoch 44/100
# 19/19 [==============================] - 5s 240ms/step - loss: 1.3989 - accuracy: 0.4834 - val_loss: 1.4364 - val_accuracy: 0.4615
# Epoch 45/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.3200 - accuracy: 0.5430 - val_loss: 1.4203 - val_accuracy: 0.4615
# Epoch 46/100
# 19/19 [==============================] - 4s 233ms/step - loss: 1.2697 - accuracy: 0.6159 - val_loss: 1.4438 - val_accuracy: 0.4923
# Epoch 47/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.2009 - accuracy: 0.5563 - val_loss: 1.4680 - val_accuracy: 0.4462
# Epoch 48/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.2883 - accuracy: 0.5166 - val_loss: 1.3932 - val_accuracy: 0.4769
# Epoch 49/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.2694 - accuracy: 0.5629 - val_loss: 1.3967 - val_accuracy: 0.4769
# Epoch 50/100
# 19/19 [==============================] - 4s 233ms/step - loss: 1.2719 - accuracy: 0.5563 - val_loss: 1.4250 - val_accuracy: 0.4923
# Epoch 51/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.3003 - accuracy: 0.5364 - val_loss: 1.4518 - val_accuracy: 0.4615
# Epoch 52/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.0893 - accuracy: 0.5894 - val_loss: 1.3978 - val_accuracy: 0.5538
# Epoch 53/100
# 19/19 [==============================] - 4s 237ms/step - loss: 1.1747 - accuracy: 0.5828 - val_loss: 1.4353 - val_accuracy: 0.5231
# Epoch 54/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.3188 - accuracy: 0.5232 - val_loss: 1.5227 - val_accuracy: 0.4923
# Epoch 55/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.1870 - accuracy: 0.6424 - val_loss: 1.6036 - val_accuracy: 0.5231
# Epoch 56/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.2807 - accuracy: 0.5430 - val_loss: 1.3610 - val_accuracy: 0.4769
# Epoch 57/100
# 19/19 [==============================] - 5s 239ms/step - loss: 1.2663 - accuracy: 0.6424 - val_loss: 1.3960 - val_accuracy: 0.5077
# Epoch 58/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.0716 - accuracy: 0.6026 - val_loss: 1.4052 - val_accuracy: 0.5231
# Epoch 59/100
# 19/19 [==============================] - 4s 238ms/step - loss: 1.1321 - accuracy: 0.5828 - val_loss: 1.4471 - val_accuracy: 0.4308
# Epoch 60/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.1497 - accuracy: 0.5762 - val_loss: 1.3665 - val_accuracy: 0.4923
# Epoch 61/100
# 19/19 [==============================] - 4s 238ms/step - loss: 1.0892 - accuracy: 0.6026 - val_loss: 1.4283 - val_accuracy: 0.4462
# Epoch 62/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.0802 - accuracy: 0.6358 - val_loss: 1.4481 - val_accuracy: 0.4308
# Epoch 63/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.1569 - accuracy: 0.6424 - val_loss: 1.3607 - val_accuracy: 0.5077
# Epoch 64/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.1783 - accuracy: 0.6225 - val_loss: 1.3241 - val_accuracy: 0.5692
# Epoch 65/100
# 19/19 [==============================] - 4s 237ms/step - loss: 1.0691 - accuracy: 0.6490 - val_loss: 1.3701 - val_accuracy: 0.5077
# Epoch 66/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.0886 - accuracy: 0.5828 - val_loss: 1.4205 - val_accuracy: 0.4769
# Epoch 67/100
# 19/19 [==============================] - 4s 237ms/step - loss: 1.1796 - accuracy: 0.5695 - val_loss: 1.3758 - val_accuracy: 0.4462
# Epoch 68/100
# 19/19 [==============================] - 4s 234ms/step - loss: 1.1113 - accuracy: 0.6490 - val_loss: 1.3025 - val_accuracy: 0.5385
# Epoch 69/100
# 19/19 [==============================] - 5s 242ms/step - loss: 1.2034 - accuracy: 0.5563 - val_loss: 1.3425 - val_accuracy: 0.4923
# Epoch 70/100
# 19/19 [==============================] - 4s 238ms/step - loss: 1.1120 - accuracy: 0.5960 - val_loss: 1.3106 - val_accuracy: 0.5538
# Epoch 71/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.0841 - accuracy: 0.6490 - val_loss: 1.3849 - val_accuracy: 0.4615
# Epoch 72/100
# 19/19 [==============================] - 4s 235ms/step - loss: 0.9672 - accuracy: 0.6689 - val_loss: 1.4402 - val_accuracy: 0.4769
# Epoch 73/100
# 19/19 [==============================] - 4s 237ms/step - loss: 1.1408 - accuracy: 0.6026 - val_loss: 1.3518 - val_accuracy: 0.5538
# Epoch 74/100
# 19/19 [==============================] - 4s 235ms/step - loss: 1.1043 - accuracy: 0.6093 - val_loss: 1.3801 - val_accuracy: 0.4769
# Epoch 75/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.0519 - accuracy: 0.6490 - val_loss: 1.3206 - val_accuracy: 0.4923
# Epoch 76/100
# 19/19 [==============================] - 4s 235ms/step - loss: 0.9581 - accuracy: 0.6954 - val_loss: 1.3197 - val_accuracy: 0.5385
# Epoch 77/100
# 19/19 [==============================] - 5s 237ms/step - loss: 1.0267 - accuracy: 0.6623 - val_loss: 1.3300 - val_accuracy: 0.5231
# Epoch 78/100
# 19/19 [==============================] - 4s 236ms/step - loss: 1.0397 - accuracy: 0.6424 - val_loss: 1.4131 - val_accuracy: 0.5385

# %%
# Print the training and validation accuracy/loss
train_accuracy = history.history['accuracy'][-1]
val_accuracy = history.history['val_accuracy'][-1]
train_loss = history.history['loss'][-1]
val_loss = history.history['val_loss'][-1]

print(f"Training Accuracy: {train_accuracy}")
print(f"Validation Accuracy: {val_accuracy}")
print(f"Training Loss: {train_loss}")
print(f"Validation Loss: {val_loss}")
# Out:
# Training Accuracy: 0.6423841118812561
# Validation Accuracy: 0.5384615659713745
# Training Loss: 1.0396556854248047
# Validation Loss: 1.4130983352661133

# %%
# Generate classification report
from sklearn.metrics import classification_report
y_pred = np.argmax(fusion_model.predict([X_test_video, X_test_audio]), axis=1)
print(classification_report(y_test, y_pred, target_names=CLASS_NAMES))
# Out:
# 3/3 [==============================] - 1s 134ms/step
#               precision    recall  f1-score   support
#
#        Angry       0.50      0.11      0.18         9
#      Disgust       0.25      0.40      0.31         5
#         Fear       0.80      0.40      0.53        10
#        Happy       0.67      0.33      0.44        12
#      Neutral       1.00      1.00      1.00        12
#          Sad       0.55      0.67      0.60         9
#     Surprise       0.29      0.75      0.41         8
#
#     accuracy                           0.54        65
#    macro avg       0.58      0.52      0.50        65
# weighted avg       0.63      0.54      0.53        65

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the History object returned by model.fit()

# Plot training & validation accuracy values
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the History object returned by model.fit()

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fusion_model.save('E:\\Capstone\\400 C code\\models\\h5 models\\emotion_vgg16.h5')
# Out:
# c:\Python10\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import confusion_matrix

# Generate confusion matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print(confusion_matrix)
# Out:
# [[ 1  3  0  1  0  2  2]
#  [ 0  2  0  0  0  2  1]
#  [ 0  0  4  0  0  0  6]
#  [ 0  2  0  4  0  1  5]
#  [ 0  0  0  0 12  0  0]
#  [ 1  1  0  0  0  6  1]
#  [ 0  0  1  1  0  0  6]]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix # Re-import the function

# Generate confusion matrix using the imported function
cm = confusion_matrix(y_test, y_pred)

# Set up the visualization
sns.set(font_scale=1.4)  # Increase font size
plt.figure(figsize=(8, 6))  # Set figure size

# Create the heatmap using cm
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)

# Add labels and title
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("Actual", fontsize=12)
plt.title("Confusion Matrix", fontsize=14)
plt.tight_layout()  # Improve spacing

# Show the plot
plt.show()
