# %%
import os
import cv2
import numpy as np
import librosa
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import os
import cv2
import numpy as np
import librosa
from tensorflow.keras.preprocessing.sequence import pad_sequences

def extract_frames(video_path, num_frames=30):
    try:
        cap = cv2.VideoCapture(video_path)
        frames = []
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        frame_interval = max(total_frames // num_frames, 1)

        for i in range(num_frames):
            cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)
            ret, frame = cap.read()
            if ret:
                frame = cv2.resize(frame, (224, 224))
                frames.append(frame)
            else:
                break

        cap.release()
        if len(frames) == 0:
            raise ValueError("No frames extracted")
        return np.array(frames)
    except Exception as e:
        print(f"Error extracting frames from {video_path}: {e}")
        return None

def extract_audio_features(audio_path, n_mfcc=40, max_pad_len=862):
    try:
        y, sr = librosa.load(audio_path, sr=None)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        if mfcc.shape[1] < max_pad_len:
            pad_width = max_pad_len - mfcc.shape[1]
            mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')
        else:
            mfcc = mfcc[:, :max_pad_len]
        return mfcc.T
    except Exception as e:
        print(f"Error extracting audio features from {audio_path}: {e}")
        return None

# Paths to dataset
DATASET_PATH = 'E:\\Capstone\\Short Dataset 2'
CLASS_NAMES = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

video_data = []
audio_data = []
labels = []

for class_name in CLASS_NAMES:
    class_path = os.path.join(DATASET_PATH, class_name)
    for video_name in os.listdir(class_path):
        video_path = os.path.join(class_path, video_name)
        if not video_name.endswith('.mp4'):
            continue
        frames = extract_frames(video_path)
        audio_features = extract_audio_features(video_path)

        if frames is not None and audio_features is not None:
            video_data.append(frames)
            audio_data.append(audio_features)
            labels.append(CLASS_NAMES.index(class_name))
        else:
            print(f"Skipping {video_name} due to insufficient data")

# Pad video sequences to a uniform length
video_data_padded = pad_sequences(video_data, padding='post', dtype='float32')

audio_data = pad_sequences(audio_data, padding='post', dtype='float32')  # Pad sequences to the same length
labels = np.array(labels)

print("Video data shape:", video_data_padded.shape) # Use the padded video data
print("Audio data shape:", audio_data.shape)
print("Labels shape:", labels.shape)
# Out:
# C:\Users\ehsan\AppData\Local\Temp\ipykernel_15128\237151489.py:33: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# c:\Python10\lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# C:\Users\ehsan\AppData\Local\Temp\ipykernel_15128\237151489.py:33: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# c:\Python10\lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Video data shape: (350, 30, 224, 224, 3)
# Audio data shape: (350, 862, 40)
# Labels shape: (350,)

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
import tensorflow as tf

# Load pre-trained MobileNetV2 model + higher level layers
base_model = MobileNetV2(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
video_model = Model(inputs=base_model.input, outputs=x)

# Extract features from each frame set
video_features = []
for frames in video_data:
    features = video_model.predict(frames)
    video_features.append(features.mean(axis=0))  # Average features over frames

video_features = np.array(video_features)
print("Video features shape:", video_features.shape)
# Out:
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python10\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 367ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 355ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 317ms/step
# Video features shape: (350, 1280)

# %%
# from tensorflow.keras.applications import VGG16
# from tensorflow.keras.models import Model
# import tensorflow as tf

# # Load pre-trained VGG16 model + higher level layers
# base_model = VGG16(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
# x = base_model.output
# x = tf.keras.layers.GlobalAveragePooling2D()(x)
# video_model = Model(inputs=base_model.input, outputs=x)

# # Extract features from each frame set
# video_features = []
# for frames in video_data:
#     features = video_model.predict(frames)
#     video_features.append(features.mean(axis=0))  # Average features over frames

# video_features = np.array(video_features)
# print("Video features shape:", video_features.shape)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      12 video_features = []
#      13 for frames in video_data:
# ---> 14     features = video_model.predict(frames)
#      15     video_features.append(features.mean(axis=0))  # Average features over frames
#      17 video_features = np.array(video_features)
#
# File c:\Python10\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python10\lib\site-packages\keras\src\engine\training.py:2655, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2653 for step in data_handler.steps():
#    2654     callbacks.on_predict_batch_begin(step)
# -> 2655     tmp_batch_outputs = self.predict_function(iterator)
#    2656     if data_handler.should_sync:
#    2657         context.async_wait()
#
# File c:\Python10\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:877, in Function._call(self, *args, **kwds)
#     874 self._lock.release()
#     875 # In this case we have not created variables on the first call. So we can
#     876 # run the first trace but we should fail if variables are created.
# --> 877 results = tracing_compilation.call_function(
#     878     args, kwds, self._variable_creation_config
#     879 )
#     880 if self._created_variables:
#     881   raise ValueError("Creating variables on a non-first call to a function"
#     882                    " decorated with tf.function.")
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File c:\Python10\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import train_test_split

X_train_video, X_test_video, X_train_audio, X_test_audio, y_train, y_test = train_test_split(
    video_features, audio_data, labels, test_size=0.3, random_state=42)

# Ensure audio data shape compatibility
X_train_audio = np.expand_dims(X_train_audio, -1)
X_test_audio = np.expand_dims(X_test_audio, -1)

print("Train video shape:", X_train_video.shape)
print("Test video shape:", X_test_video.shape)
print("Train audio shape:", X_train_audio.shape)
print("Test audio shape:", X_test_audio.shape)
print("Train labels shape:", y_train.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Train video shape: (245, 1280)
# Test video shape: (105, 1280)
# Train audio shape: (245, 862, 40, 1)
# Test audio shape: (105, 862, 40, 1)
# Train labels shape: (245,)
# Test labels shape: (105,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, concatenate, Dropout
from tensorflow.keras.regularizers import l2

video_input = Input(shape=(1280,))  # Adjust input shape to match actual video feature dimensions
video_dense = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(video_input)
video_dropout = Dropout(0.5)(video_dense)

# Audio model
audio_input = Input(shape=(862, 40))
audio_lstm = LSTM(128, kernel_regularizer=l2(0.001))(audio_input)
audio_dropout = Dropout(0.5)(audio_lstm)

# Fusion model
merged = concatenate([video_dropout, audio_dropout])
dense_1 = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(merged)
dense_1_dropout = Dropout(0.5)(dense_1)
output = Dense(len(CLASS_NAMES), activation='softmax')(dense_1_dropout)

fusion_model = Model(inputs=[video_input, audio_input], outputs=output)
fusion_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
fusion_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 1280)]               0         []
#
#  input_7 (InputLayer)        [(None, 862, 40)]            0         []
#
#  dense_6 (Dense)             (None, 128)                  163968    ['input_6[0][0]']
#
#  lstm_2 (LSTM)               (None, 128)                  86528     ['input_7[0][0]']
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['dense_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 128)                  0         ['lstm_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 256)                  0         ['dropout_6[0][0]',
#  )                                                                   'dropout_7[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  32896     ['concatenate_2[0][0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 7)                    903       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 284295 (1.08 MB)
# Trainable params: 284295 (1.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = fusion_model.fit(
    [X_train_video, X_train_audio], y_train,
    validation_data=([X_test_video, X_test_audio], y_test),
    epochs=100, batch_size=8,
    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 31/31 [==============================] - 11s 265ms/step - loss: 2.8353 - accuracy: 0.0980 - val_loss: 2.3462 - val_accuracy: 0.1143
# Epoch 2/100
# 31/31 [==============================] - 8s 248ms/step - loss: 2.2998 - accuracy: 0.1878 - val_loss: 2.1895 - val_accuracy: 0.1714
# Epoch 3/100
# 31/31 [==============================] - 8s 251ms/step - loss: 2.1990 - accuracy: 0.1959 - val_loss: 2.1735 - val_accuracy: 0.1714
# Epoch 4/100
# 31/31 [==============================] - 8s 248ms/step - loss: 2.1659 - accuracy: 0.2408 - val_loss: 2.1126 - val_accuracy: 0.2476
# Epoch 5/100
# 31/31 [==============================] - 8s 249ms/step - loss: 2.1245 - accuracy: 0.2082 - val_loss: 2.1071 - val_accuracy: 0.2286
# Epoch 6/100
# 31/31 [==============================] - 8s 249ms/step - loss: 2.1491 - accuracy: 0.1878 - val_loss: 2.1148 - val_accuracy: 0.2190
# Epoch 7/100
# 31/31 [==============================] - 8s 246ms/step - loss: 2.1091 - accuracy: 0.2000 - val_loss: 2.1029 - val_accuracy: 0.2190
# Epoch 8/100
# 31/31 [==============================] - 8s 250ms/step - loss: 2.0966 - accuracy: 0.2000 - val_loss: 2.0715 - val_accuracy: 0.2095
# Epoch 9/100
# 31/31 [==============================] - 8s 248ms/step - loss: 2.0433 - accuracy: 0.2286 - val_loss: 2.0317 - val_accuracy: 0.2000
# Epoch 10/100
# 31/31 [==============================] - 8s 249ms/step - loss: 2.0464 - accuracy: 0.2204 - val_loss: 2.0377 - val_accuracy: 0.1524
# Epoch 11/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.9834 - accuracy: 0.2449 - val_loss: 2.0236 - val_accuracy: 0.1810
# Epoch 12/100
# 31/31 [==============================] - 8s 249ms/step - loss: 1.9961 - accuracy: 0.2122 - val_loss: 1.9908 - val_accuracy: 0.1905
# Epoch 13/100
# 31/31 [==============================] - 8s 248ms/step - loss: 1.9848 - accuracy: 0.2408 - val_loss: 1.9671 - val_accuracy: 0.1810
# Epoch 14/100
# 31/31 [==============================] - 8s 250ms/step - loss: 1.8911 - accuracy: 0.2898 - val_loss: 1.9391 - val_accuracy: 0.2000
# Epoch 15/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.9652 - accuracy: 0.2408 - val_loss: 1.9537 - val_accuracy: 0.1905
# Epoch 16/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.9354 - accuracy: 0.2327 - val_loss: 1.9106 - val_accuracy: 0.2000
# Epoch 17/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.8459 - accuracy: 0.2694 - val_loss: 1.9209 - val_accuracy: 0.1810
# Epoch 18/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.9098 - accuracy: 0.2653 - val_loss: 1.9078 - val_accuracy: 0.2190
# Epoch 19/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.8830 - accuracy: 0.2122 - val_loss: 1.9114 - val_accuracy: 0.2095
# Epoch 20/100
# 31/31 [==============================] - 8s 261ms/step - loss: 1.8459 - accuracy: 0.2653 - val_loss: 1.9002 - val_accuracy: 0.1810
# Epoch 21/100
# 31/31 [==============================] - 8s 262ms/step - loss: 1.8489 - accuracy: 0.2898 - val_loss: 1.8767 - val_accuracy: 0.2095
# Epoch 22/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.8815 - accuracy: 0.2571 - val_loss: 1.8645 - val_accuracy: 0.2381
# Epoch 23/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.8257 - accuracy: 0.2612 - val_loss: 1.8996 - val_accuracy: 0.2095
# Epoch 24/100
# 31/31 [==============================] - 8s 253ms/step - loss: 1.8375 - accuracy: 0.2735 - val_loss: 1.8363 - val_accuracy: 0.2571
# Epoch 25/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.7997 - accuracy: 0.2857 - val_loss: 1.8350 - val_accuracy: 0.2000
# Epoch 26/100
# 31/31 [==============================] - 8s 258ms/step - loss: 1.7532 - accuracy: 0.3265 - val_loss: 1.8177 - val_accuracy: 0.2095
# Epoch 27/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.8191 - accuracy: 0.2571 - val_loss: 1.7964 - val_accuracy: 0.2571
# Epoch 28/100
# 31/31 [==============================] - 8s 253ms/step - loss: 1.7925 - accuracy: 0.2612 - val_loss: 1.8203 - val_accuracy: 0.2476
# Epoch 29/100
# 31/31 [==============================] - 8s 250ms/step - loss: 1.7623 - accuracy: 0.2776 - val_loss: 1.7910 - val_accuracy: 0.2286
# Epoch 30/100
# 31/31 [==============================] - 8s 250ms/step - loss: 1.7883 - accuracy: 0.2612 - val_loss: 1.8029 - val_accuracy: 0.2190
# Epoch 31/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.7533 - accuracy: 0.2898 - val_loss: 1.7824 - val_accuracy: 0.2190
# Epoch 32/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.7776 - accuracy: 0.2571 - val_loss: 1.7747 - val_accuracy: 0.2571
# Epoch 33/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.7617 - accuracy: 0.2898 - val_loss: 1.7723 - val_accuracy: 0.2381
# Epoch 34/100
# 31/31 [==============================] - 8s 254ms/step - loss: 1.7784 - accuracy: 0.2776 - val_loss: 1.7627 - val_accuracy: 0.2476
# Epoch 35/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.7407 - accuracy: 0.2612 - val_loss: 1.7402 - val_accuracy: 0.2381
# Epoch 36/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.7141 - accuracy: 0.2571 - val_loss: 1.7498 - val_accuracy: 0.2286
# Epoch 37/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.7010 - accuracy: 0.2653 - val_loss: 1.7239 - val_accuracy: 0.2857
# Epoch 38/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6382 - accuracy: 0.3224 - val_loss: 1.7193 - val_accuracy: 0.2190
# Epoch 39/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.7328 - accuracy: 0.3306 - val_loss: 1.7553 - val_accuracy: 0.2476
# Epoch 40/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6979 - accuracy: 0.2980 - val_loss: 1.7396 - val_accuracy: 0.2857
# Epoch 41/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6542 - accuracy: 0.3102 - val_loss: 1.7501 - val_accuracy: 0.2286
# Epoch 42/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.7026 - accuracy: 0.3020 - val_loss: 1.7244 - val_accuracy: 0.2286
# Epoch 43/100
# 31/31 [==============================] - 8s 253ms/step - loss: 1.7022 - accuracy: 0.3347 - val_loss: 1.7317 - val_accuracy: 0.2190
# Epoch 44/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6697 - accuracy: 0.3184 - val_loss: 1.7058 - val_accuracy: 0.2476
# Epoch 45/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6789 - accuracy: 0.2980 - val_loss: 1.7105 - val_accuracy: 0.3048
# Epoch 46/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6736 - accuracy: 0.2980 - val_loss: 1.7288 - val_accuracy: 0.2286
# Epoch 47/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.7205 - accuracy: 0.2939 - val_loss: 1.7526 - val_accuracy: 0.2381
# Epoch 48/100
# 31/31 [==============================] - 8s 250ms/step - loss: 1.6746 - accuracy: 0.3184 - val_loss: 1.7329 - val_accuracy: 0.2286
# Epoch 49/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6356 - accuracy: 0.3143 - val_loss: 1.7049 - val_accuracy: 0.2952
# Epoch 50/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6167 - accuracy: 0.3184 - val_loss: 1.7155 - val_accuracy: 0.2476
# Epoch 51/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6499 - accuracy: 0.3102 - val_loss: 1.6973 - val_accuracy: 0.3048
# Epoch 52/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6076 - accuracy: 0.3633 - val_loss: 1.6915 - val_accuracy: 0.3048
# Epoch 53/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6233 - accuracy: 0.3224 - val_loss: 1.6915 - val_accuracy: 0.3143
# Epoch 54/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6670 - accuracy: 0.3265 - val_loss: 1.7335 - val_accuracy: 0.2952
# Epoch 55/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6789 - accuracy: 0.3061 - val_loss: 1.6890 - val_accuracy: 0.3238
# Epoch 56/100
# 31/31 [==============================] - 8s 253ms/step - loss: 1.6021 - accuracy: 0.3347 - val_loss: 1.7148 - val_accuracy: 0.2952
# Epoch 57/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6298 - accuracy: 0.3224 - val_loss: 1.7194 - val_accuracy: 0.3048
# Epoch 58/100
# 31/31 [==============================] - 8s 253ms/step - loss: 1.6410 - accuracy: 0.3388 - val_loss: 1.6979 - val_accuracy: 0.2190
# Epoch 59/100
# 31/31 [==============================] - 8s 268ms/step - loss: 1.6365 - accuracy: 0.3265 - val_loss: 1.7230 - val_accuracy: 0.2476
# Epoch 60/100
# 31/31 [==============================] - 8s 256ms/step - loss: 1.6259 - accuracy: 0.3551 - val_loss: 1.7301 - val_accuracy: 0.3048
# Epoch 61/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.5600 - accuracy: 0.3673 - val_loss: 1.7054 - val_accuracy: 0.2762
# Epoch 62/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6728 - accuracy: 0.3184 - val_loss: 1.6658 - val_accuracy: 0.3619
# Epoch 63/100
# 31/31 [==============================] - 8s 251ms/step - loss: 1.6188 - accuracy: 0.3633 - val_loss: 1.6773 - val_accuracy: 0.3524
# Epoch 64/100
# 31/31 [==============================] - 9s 280ms/step - loss: 1.7019 - accuracy: 0.3143 - val_loss: 1.6800 - val_accuracy: 0.2571
# Epoch 65/100
# 31/31 [==============================] - 9s 305ms/step - loss: 1.5951 - accuracy: 0.3347 - val_loss: 1.7109 - val_accuracy: 0.3619
# Epoch 66/100
# 31/31 [==============================] - 9s 297ms/step - loss: 1.5881 - accuracy: 0.3510 - val_loss: 1.6870 - val_accuracy: 0.2857
# Epoch 67/100
# 31/31 [==============================] - 8s 259ms/step - loss: 1.5801 - accuracy: 0.3837 - val_loss: 1.7539 - val_accuracy: 0.2952
# Epoch 68/100
# 31/31 [==============================] - 8s 256ms/step - loss: 1.5848 - accuracy: 0.3347 - val_loss: 1.6798 - val_accuracy: 0.3238
# Epoch 69/100
# 31/31 [==============================] - 8s 253ms/step - loss: 1.6325 - accuracy: 0.3306 - val_loss: 1.6912 - val_accuracy: 0.2762
# Epoch 70/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6359 - accuracy: 0.3796 - val_loss: 1.7148 - val_accuracy: 0.3619
# Epoch 71/100
# 31/31 [==============================] - 8s 254ms/step - loss: 1.6213 - accuracy: 0.3469 - val_loss: 1.6716 - val_accuracy: 0.2667
# Epoch 72/100
# 31/31 [==============================] - 8s 252ms/step - loss: 1.6035 - accuracy: 0.3592 - val_loss: 1.6734 - val_accuracy: 0.3238

# %%
# Print the training and validation accuracy/loss
train_accuracy = history.history['accuracy'][-1]
val_accuracy = history.history['val_accuracy'][-1]
train_loss = history.history['loss'][-1]
val_loss = history.history['val_loss'][-1]

print(f"Training Accuracy: {train_accuracy}")
print(f"Validation Accuracy: {val_accuracy}")
print(f"Training Loss: {train_loss}")
print(f"Validation Loss: {val_loss}")
# Out:
# Training Accuracy: 0.359183669090271
# Validation Accuracy: 0.32380953431129456
# Training Loss: 1.6034618616104126
# Validation Loss: 1.673431396484375

# %%
# Generate classification report
from sklearn.metrics import classification_report
y_pred = np.argmax(fusion_model.predict([X_test_video, X_test_audio]), axis=1)
print(classification_report(y_test, y_pred, target_names=CLASS_NAMES))
# Out:
# 4/4 [==============================] - 1s 151ms/step
#               precision    recall  f1-score   support
#
#        Angry       0.24      0.88      0.38        16
#      Disgust       0.00      0.00      0.00        17
#         Fear       0.26      0.38      0.31        13
#        Happy       1.00      0.07      0.12        15
#      Neutral       1.00      0.86      0.92        14
#          Sad       0.43      0.50      0.46        12
#     Surprise       0.00      0.00      0.00        18
#
#     accuracy                           0.36       105
#    macro avg       0.42      0.38      0.31       105
# weighted avg       0.39      0.36      0.29       105
# c:\Python10\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python10\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python10\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the History object returned by model.fit()

# Plot training & validation accuracy values
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the History object returned by model.fit()

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fusion_model.save('E:\\Capstone\\400 C code\\models\\h5 models\\emotion_mobileNetV3_run2.h5')
# Out:
# c:\Python10\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import confusion_matrix

# Generate confusion matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# Print the confusion matrix
print(confusion_matrix)
# Out:
# [[14  0  1  0  0  1  0]
#  [15  0  1  0  0  0  1]
#  [ 5  0  5  0  0  3  0]
#  [ 9  0  4  1  0  1  0]
#  [ 0  0  2  0 12  0  0]
#  [ 5  0  1  0  0  6  0]
#  [10  0  5  0  0  3  0]]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix # Re-import the function

# Generate confusion matrix using the imported function
cm = confusion_matrix(y_test, y_pred)

# Set up the visualization
sns.set(font_scale=1.4)  # Increase font size
plt.figure(figsize=(8, 6))  # Set figure size

# Create the heatmap using cm
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)

# Add labels and title
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("Actual", fontsize=12)
plt.title("Confusion Matrix", fontsize=14)
plt.tight_layout()  # Improve spacing

# Show the plot
plt.show()
